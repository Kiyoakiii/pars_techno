# %%
from selenium import webdriver
import numpy as np

import time
from selenium import webdriver

from selenium.webdriver.common.by import By

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
df1 = pd.read_csv(r'A:\Учёба\практика 2 курс\data\citilink/pk/data.csv')
df2 = pd.read_csv(r'A:\Учёба\практика 2 курс\data\eldorado/pk/data.csv')

# %%
df1.replace("есть", 1, inplace=True)
df2.replace("есть", 1, inplace=True)

df1.replace("да", 1, inplace=True)
df2.replace("да", 1, inplace=True)

df1.replace("нет", 1, inplace=True)
df2.replace("нет", 1, inplace=True)

df1.replace("Нет", 1, inplace=True)
df2.replace("Нет", 1, inplace=True)

df1.replace("Есть ", 1, inplace=True)
df2.replace("Есть ", 1, inplace=True)

df1.replace("Есть", 1, inplace=True)
df2.replace("Есть", 1, inplace=True)

# %%
df1 = df1.fillna(0)
df2 = df2.fillna(0)

# %%
columns1 = df1.columns
columns2 = df2.columns

# %%
set(columns1) & set(columns2)
# Out:
# {'link',
#  'Гарантия',
#  'Клавиатура',
#  'Количество отзывов',
#  'Мышь',
#  'Название',
#  'Операционная система',
#  'Разъем для микрофона',
#  'Разъем для наушников',
#  'Рейтинг',
#  'Стандарт Wi-Fi',
#  'Тип вилки',
#  'Цена'}

# %%
df1[df1.ne(0)].count().sort_values(ascending=False)
# Out:
# link                                      428
# Название                                  428
# Цена                                      428
# Рейтинг                                   421
# Гарантийное                               397
# Гарантия                                  397
# Цвет корпуса                              397
# Операционная система                      396
# Тип графического контроллера              394
# Тип кабельной сети (разъем RJ-45)         394
# Процессор                                 394
# Вес упаковки (ед)                         394
# Оперативная память                        394
# Количество ядер процессора                394
# Размеры корпуса (ШхВхГ)                   393
# Разъемов USB 3.0                          393
# Бренд                                     391
# Процессор, частота                        388
# Графика                                   387
# Разъемов HDMI                             385
# Габариты упаковки (ед) ДхШхВ              383
# Объем SSD                                 379
# Вес товара                                378
# Блок питания                              369
# Разъемов USB 2.0                          365
# Тип корпуса                               358
# Чипсет материнской платы                  351
# Разъем для наушников                      317
# Максимальный объем оперативной памяти     314
# Разъем для микрофона                      313
# Сокет процессора                          245
# Разъемов PS/2                             241
# Разъемов D-Sub                            199
# Разъемов DisplayPort                      191
# Тип блока питания                         159
# Поддержка Bluetooth                       108
# Поддержка Wi-Fi                           108
# Стандарт Wi-Fi                            106
# Разъемов DVI                              105
# Количество высокопроизводительных ядер     99
# Стандарт Bluetooth                         97
# Разрядность ОС                             86
# Разъем наушники/микрофон                   78
# Количество отзывов                         76
# Разъемов USB 3.1                           68
# Мышь                                       56
# Клавиатура                                 54
# Разъемов USB 3.0 (Type-C)                  51
# Жесткий диск                               51
# Клавиатура с русскими буквами              47
# Частота энергоэффективных ядер             40
# Количество энергоэффективных ядер          40
# Разъемов USB 3.1 (Type-C)                  39
# Разъемов RS-232                            38
# Особенности оперативной памяти             35
# Кард-ридер                                 25
# Особенности жестких дисков                 23
# Особенности                                21
# Оптический привод                          15
# Поддержка карт памяти                      14
# Комплектация                               12
# Входное напряжение (мин)                   12
# Входное напряжение (макс)                  12
# Тип вилки                                  12
# Отделка корпуса                            11
# Разъемов Thunderbolt 4                     10
# Встроенные динамики                        10
# Страна производства                         9
# Дополнительно в комплекте                   9
# Размер крепления VESA                       9
# Особенности графического контроллера        9
# Частота электросети                         8
# Разъемов USB 3.2 (Type-C)                   8
# Число ядер GPU                              6
# Разъемов USB 4.0                            4
# Особенности ОС                              3
# Разъемов USB 2.0 (Type-C)                   2
# Монитор в комплекте                         2
# Разъемов Thunderbolt 3                      2
# Объем второго SSD                           2
# Возможность монтажа в стойку                1
# Экран с поддержкой 3D                       1
# Особенности процессора                      1
# Поддержка Intel Optane                      1
# Буферная память HDD                         1
# Модель монитора                             1
# Диагональ экрана                            1
# Разрешение экрана                           1
# Яркость экрана                              1
# Время отклика                               1
# Угол обзора                                 1
# dtype: int64

# %%
df1['Графика']
# Out:
# 0           NVIDIA GeForce RTX 3060 - 12288 Мб
# 1                       Intel UHD Graphics 630
# 2                                            0
# 3                       Intel UHD Graphics 630
# 4            NVIDIA GeForce RTX 3050 - 8192 Мб
# 5          NVIDIA GeForce RTX 3060Ti - 8192 Мб
# 6      NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 7      NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 8            NVIDIA GeForce RTX 3050 - 8192 Мб
# 9            NVIDIA GeForce GTX 1650 - 4096 Мб
# 10                                           0
# 11                      Intel UHD Graphics 610
# 12                      Intel UHD Graphics 730
# 13           NVIDIA GeForce GTX 1650 - 4096 Мб
# 14                         AMD Radeon Graphics
# 15                      Intel UHD Graphics 610
# 16                         AMD Radeon Graphics
# 17                      Intel UHD Graphics 730
# 18                      Intel UHD Graphics 730
# 19          NVIDIA GeForce RTX 3060 - 12288 Мб
# 20             NVIDIA GeForce GT1030 - 2048 Мб
# 21                          Intel UHD Graphics
# 22                      Intel UHD Graphics 610
# 23                                           0
# 24           NVIDIA GeForce RTX 3050 - 8192 Мб
# 25                      Intel UHD Graphics 630
# 26           NVIDIA GeForce GTX 1630 - 4096 Мб
# 27                                           0
# 28     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 29         NVIDIA GeForce RTX 3060Ti - 8192 Мб
# 30           NVIDIA GeForce RTX 3050 - 8192 Мб
# 31     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 32           NVIDIA GeForce GTX 1630 - 4096 Мб
# 33      Intel GeForce GTX 1660 Super - 6144 Мб
# 34          NVIDIA GeForce RTX 3060 - 12288 Мб
# 35     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 36           NVIDIA GeForce GTX 1650 - 4096 Мб
# 37         NVIDIA GeForce RTX 3070Ti - 8192 Мб
# 38          NVIDIA GeForce RTX 3060 - 12288 Мб
# 39                      Intel UHD Graphics 600
# 40                      Intel UHD Graphics 730
# 41                      Intel UHD Graphics 750
# 42     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 43           NVIDIA GeForce RTX 3050 - 8192 Мб
# 44                           AMD Radeon Vega 3
# 45             NVIDIA GeForce GT1030 - 2048 Мб
# 46          NVIDIA GeForce RTX 3060 - 12288 Мб
# 47                      Intel UHD Graphics 630
# 48           NVIDIA GeForce GTX 1630 - 4096 Мб
# 49                      Intel UHD Graphics 730
# 50          NVIDIA GeForce RTX 3060 - 12288 Мб
# 51           NVIDIA GeForce GTX 1650 - 4096 Мб
# 52           NVIDIA GeForce GTX 1660 - 6144 Мб
# 53                      Intel UHD Graphics 770
# 54     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 55                      Intel UHD Graphics 600
# 56          NVIDIA GeForce RTX 3080 - 10240 Мб
# 57                      Intel UHD Graphics 630
# 58     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 59            Intel GeForce RTX 3050 - 8192 Мб
# 60                      Intel UHD Graphics 610
# 61                      Intel UHD Graphics 730
# 62                                           0
# 63                         AMD Radeon Graphics
# 64                                           0
# 65                          Intel UHD Graphics
# 66                          Intel UHD Graphics
# 67                          Intel UHD Graphics
# 68          NVIDIA GeForce RTX 3060 - 12288 Мб
# 69                         AMD Radeon Graphics
# 70                          Intel UHD Graphics
# 71         NVIDIA GeForce RTX 3070Ti - 8192 Мб
# 72         NVIDIA GeForce RTX 3070Ti - 8192 Мб
# 73                                           0
# 74                         AMD Radeon Graphics
# 75                      Intel UHD Graphics 630
# 76                                           0
# 77                AMD Radeon RX 6600 - 8192 Мб
# 78           NVIDIA GeForce RTX 3050 - 8192 Мб
# 79          NVIDIA GeForce RTX 3060 - 12288 Мб
# 80           NVIDIA GeForce RTX 3050 - 8192 Мб
# 81                AMD Radeon RX 6600 - 8192 Мб
# 82           NVIDIA GeForce RTX 3070 - 8192 Мб
# 83           NVIDIA GeForce RTX 3070 - 8192 Мб
# 84          NVIDIA GeForce RTX 3060 - 12288 Мб
# 85                AMD Radeon RX 6600 - 8192 Мб
# 86          NVIDIA GeForce RTX 3060 - 12288 Мб
# 87          NVIDIA GeForce RTX 3060 - 12288 Мб
# 88                          Intel UHD Graphics
# 89           NVIDIA GeForce GTX 1030 - 2048 Мб
# 90           NVIDIA GeForce GTX 1030 - 2048 Мб
# 91          NVIDIA GeForce RTX 3060 - 12288 Мб
# 92                      Intel UHD Graphics 730
# 93                      Intel UHD Graphics 730
# 94                      Intel UHD Graphics 630
# 95             NVIDIA GeForce GT1030 - 2048 Мб
# 96             NVIDIA GeForce GT1030 - 2048 Мб
# 97             NVIDIA GeForce GT1030 - 2048 Мб
# 98     NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 99                                           0
# 100    NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 101                        AMD Radeon Graphics
# 102                        AMD Radeon Graphics
# 103                                          0
# 104                     Intel UHD Graphics 630
# 105                     Intel UHD Graphics 770
# 106                     Intel UHD Graphics 770
# 107                     Intel UHD Graphics 730
# 108          NVIDIA GeForce GTX 1650 - 4096 Мб
# 109                                          0
# 110        NVIDIA GeForce RTX 3060Ti - 8192 Мб
# 111         NVIDIA GeForce RTX 3060 - 12288 Мб
# 112         NVIDIA GeForce RTX 3060 - 12288 Мб
# 113          NVIDIA GeForce RTX 3050 - 8192 Мб
# 114        NVIDIA GeForce RTX 3060Ti - 8192 Мб
# 115                     Intel UHD Graphics 730
# 116                     Intel UHD Graphics 730
# 117                     Intel UHD Graphics 730
# 118                     Intel UHD Graphics 730
# 119                     Intel UHD Graphics 730
# 120             NVIDIA GeForce GT710 - 2048 Мб
# 121            NVIDIA GeForce GT1030 - 2048 Мб
# 122            NVIDIA GeForce GT1030 - 2048 Мб
# 123                        AMD Radeon Graphics
# 124                        AMD Radeon Graphics
# 125                        AMD Radeon Graphics
# 126                        AMD Radeon Graphics
# 127                     Intel UHD Graphics 630
# 128          NVIDIA GeForce RTX 3050 - 8192 Мб
# 129                     Intel UHD Graphics 630
# 130                     Intel UHD Graphics 770
# 131         NVIDIA GeForce RTX 3060 - 12288 Мб
NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 360          NVIDIA GeForce GTX 1650 - 4096 Мб
# 361          NVIDIA GeForce GTX 1650 - 4096 Мб
# 362          NVIDIA GeForce GTX 1650 - 4096 Мб
# 363          NVIDIA GeForce GTX 1660 - 6144 Мб
# 364                     Intel UHD Graphics 630
# 365        NVIDIA GeForce RTX 3060Ti - 8192 Мб
# 366          NVIDIA GeForce GTX 1650 - 4096 Мб
# 367          NVIDIA GeForce GTX 1650 - 4096 Мб
# 368         NVIDIA GeForce RTX 3090 - 24576 Мб
# 369          NVIDIA GeForce GTX 1650 - 4096 Мб
# 370          NVIDIA GeForce RTX 3070 - 8192 Мб
# 371         NVIDIA GeForce RTX 3090 - 24576 Мб
# 372    NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 373            AMD Radeon RX 6700XT - 12288 Мб
# 374                     Intel UHD Graphics 610
# 375         NVIDIA GeForce RTX 3060 - 12288 Мб
# 376          NVIDIA GeForce GTX 1650 - 4096 Мб
# 377          NVIDIA GeForce GTX 1650 - 4096 Мб
# 378                     Intel UHD Graphics 610
# 379                                          0
# 380                                          0
# 381                                          0
# 382                                          0
# 383                                          0
# 384      NVIDIA GeForce RTX 4070 Ti - 12288 Мб
# 385         NVIDIA GeForce RTX 4080 - 16384 Мб
# 386          NVIDIA GeForce RTX 3050 - 8192 Мб
# 387         NVIDIA GeForce RTX 4080 - 16384 Мб
# 388         NVIDIA GeForce RTX 3060 - 12288 Мб
# 389                     Intel UHD Graphics 730
# 390                                          0
# 391                        AMD Radeon Graphics
# 392                        AMD Radeon Graphics
# 393                                          0
# 394                                          0
# 395                                          0
# 396                     Intel UHD Graphics 610
# 397         NVIDIA GeForce RTX 3060 - 12288 Мб
# 398          NVIDIA GeForce RTX 3050 - 8192 Мб
# 399         NVIDIA GeForce RTX 3060 - 12288 Мб
# 400    NVIDIA GeForce GTX 1660 Super - 6144 Мб
# 401          NVIDIA GeForce GTX 1650 - 4096 Мб
# 402                     Intel UHD Graphics 730
# 403                                          0
# 404          NVIDIA GeForce GTX 1650 - 4096 Мб
# 405                                          0
# 406                     Intel UHD Graphics 630
# 407                                          0
# 408                         Intel UHD Graphics
# 409                     Intel UHD Graphics 630
# 410                     Intel UHD Graphics 730
# 411                     Intel UHD Graphics 630
# 412                     Intel UHD Graphics 630
# 413                                          0
# 414                                          0
# 415                                          0
# 416                     Intel UHD Graphics 630
# 417                                          0
# 418                                          0
# 419                                          0
# 420                     Intel UHD Graphics 630
# 421                                          0
# 422                                          0
# 423                                          0
# 424                                          0
# 425                                          0
# 426                                          0
# 427                                          0
# Name: Графика, dtype: object

# %%
df1['Оперативная память']
# Out:
# 0         16 ГБ, DDR4, DIMM, 3200 МГц
# 1          8 ГБ, DDR4, DIMM, 2666 МГц
# 2                                   0
# 3         16 ГБ, DDR4, DIMM, 2666 МГц
# 4         16 ГБ, DDR4, DIMM, 3200 МГц
# 5         16 ГБ, DDR4, DIMM, 2933 МГц
# 6         16 ГБ, DDR4, DIMM, 3200 МГц
# 7         16 ГБ, DDR4, DIMM, 3200 МГц
# 8         16 ГБ, DDR4, DIMM, 3200 МГц
# 9                    8 ГБ, DDR4, DIMM
# 10                                  0
# 11         8 ГБ, DDR4, DIMM, 2666 МГц
# 12         8 ГБ, DDR4, DIMM, 2666 МГц
# 13        16 ГБ, DDR4, DIMM, 3200 МГц
# 14         8 ГБ, DDR4, DIMM, 3200 МГц
# 15         4 ГБ, DDR4, DIMM, 2400 МГц
# 16        16 ГБ, DDR4, DIMM, 3200 МГц
# 17         8 ГБ, DDR4, DIMM, 2666 МГц
# 18         8 ГБ, DDR4, DIMM, 3200 МГц
# 19        16 ГБ, DDR4, DIMM, 2666 МГц
# 20         8 ГБ, DDR4, DIMM, 3200 МГц
# 21     16 ГБ, DDR4, SO-DIMM, 2666 МГц
# 22                    , DDR4, SO-DIMM
# 23                              16 ГБ
# 24        16 ГБ, DDR4, DIMM, 3200 МГц
# 25         8 ГБ, DDR4, DIMM, 2666 МГц
# 26         8 ГБ, DDR4, DIMM, 3200 МГц
# 27                                  0
# 28        16 ГБ, DDR4, DIMM, 3200 МГц
# 29        16 ГБ, DDR4, DIMM, 3200 МГц
# 30     16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 31        16 ГБ, DDR4, DIMM, 3200 МГц
# 32         8 ГБ, DDR4, DIMM, 3200 МГц
# 33        16 ГБ, DDR4, DIMM, 3200 МГц
# 34                  16 ГБ, DDR4, DIMM
# 35         8 ГБ, DDR4, DIMM, 3000 МГц
# 36                  16 ГБ, DDR4, DIMM
# 37        16 ГБ, DDR4, DIMM, 3000 МГц
# 38        16 ГБ, DDR4, DIMM, 3200 МГц
# 39                    , DDR4, SO-DIMM
# 40         8 ГБ, DDR4, DIMM, 3200 МГц
# 41        16 ГБ, DDR4, DIMM, 3200 МГц
# 42        16 ГБ, DDR4, DIMM, 3200 МГц
# 43        16 ГБ, DDR4, DIMM, 3200 МГц
# 44         8 ГБ, DDR4, DIMM, 2666 МГц
# 45         8 ГБ, DDR4, DIMM, 2666 МГц
# 46                  16 ГБ, DDR4, DIMM
# 47         8 ГБ, DDR4, DIMM, 2666 МГц
# 48        16 ГБ, DDR4, DIMM, 2666 МГц
# 49         8 ГБ, DDR4, DIMM, 3200 МГц
# 50                  16 ГБ, DDR4, DIMM
# 51        16 ГБ, DDR4, DIMM, 2666 МГц
# 52        16 ГБ, DDR4, DIMM, 2400 МГц
# 53     16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 54         8 ГБ, DDR4, DIMM, 2666 МГц
# 55      4 ГБ, DDR4, SO-DIMM, 2400 МГц
# 56        32 ГБ, DDR4, DIMM, 3600 МГц
# 57         8 ГБ, DDR4, DIMM, 2666 МГц
# 58        16 ГБ, DDR4, DIMM, 2666 МГц
# 59        16 ГБ, DDR4, DIMM, 3200 МГц
# 60      4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 61         8 ГБ, DDR4, DIMM, 3200 МГц
# 62                               8 ГБ
# 63               16 ГБ, DDR4, SO-DIMM
# 64                                  0
# 65                        16 ГБ, DDR5
# 66                      12 ГБ, LPDDR5
# 67                         8 ГБ, DDR4
# 68        16 ГБ, DDR4, DIMM, 3200 МГц
# 69               16 ГБ, DDR4, SO-DIMM
# 70                         8 ГБ, DDR4
# 71        16 ГБ, DDR4, DIMM, 3200 МГц
# 72        16 ГБ, DDR4, DIMM, 3200 МГц
# 73                               8 ГБ
# 74        16 ГБ, DDR4, DIMM, 3200 МГц
# 75         8 ГБ, DDR4, DIMM, 2666 МГц
# 76                               8 ГБ
# 77        16 ГБ, DDR4, DIMM, 3200 МГц
# 78        16 ГБ, DDR4, DIMM, 3200 МГц
# 79        16 ГБ, DDR4, DIMM, 3200 МГц
# 80        16 ГБ, DDR4, DIMM, 3200 МГц
# 81        16 ГБ, DDR4, DIMM, 3200 МГц
# 82        16 ГБ, DDR4, DIMM, 3200 МГц
# 83        16 ГБ, DDR4, DIMM, 3200 МГц
# 84        16 ГБ, DDR4, DIMM, 3200 МГц
# 85        16 ГБ, DDR4, DIMM, 3200 МГц
# 86        16 ГБ, DDR4, DIMM, 3200 МГц
# 87        16 ГБ, DDR4, DIMM, 3200 МГц
# 88         8 ГБ, DDR4, DIMM, 3200 МГц
# 89         8 ГБ, DDR4, DIMM, 3200 МГц
# 90         8 ГБ, DDR4, DIMM, 3200 МГц
# 91        16 ГБ, DDR4, DIMM, 3200 МГц
# 92         8 ГБ, DDR4, DIMM, 3200 МГц
# 93         8 ГБ, DDR4, DIMM, 3200 МГц
# 94      8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 95         8 ГБ, DDR4, DIMM, 3200 МГц
# 96         8 ГБ, DDR4, DIMM, 3200 МГц
# 97         8 ГБ, DDR4, DIMM, 3200 МГц
# 98        16 ГБ, DDR4, DIMM, 2666 МГц
# 99                                  0
# 100       16 ГБ, DDR4, DIMM, 3200 МГц
# 101       16 ГБ, DDR4, DIMM, 2666 МГц
# 102        8 ГБ, DDR4, DIMM, 2666 МГц
# 103                                 0
# 104        8 ГБ, DDR4, DIMM, 2666 МГц
# 105                 16 ГБ, DDR4, DIMM
# 106       16 ГБ, DDR4, DIMM, 3200 МГц
# 107        8 ГБ, DDR4, DIMM, 3200 МГц
# 108     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 109                                 0
# 110       16 ГБ, DDR4, DIMM, 2666 МГц
# 111       16 ГБ, DDR4, DIMM, 2666 МГц
# 112       16 ГБ, DDR4, DIMM, 2666 МГц
# 113       16 ГБ, DDR4, DIMM, 2666 МГц
# 114       16 ГБ, DDR4, DIMM, 3200 МГц
# 115        8 ГБ, DDR4, DIMM, 3200 МГц
# 116       16 ГБ, DDR4, DIMM, 3200 МГц
# 117       16 ГБ, DDR4, DIMM, 3200 МГц
# 118        8 ГБ, DDR4, DIMM, 3200 МГц
# 119        8 ГБ, DDR4, DIMM, 3200 МГц
# 120       16 ГБ, DDR4, DIMM, 3200 МГц
# 121       16 ГБ, DDR4, DIMM, 2666 МГц
# 122       16 ГБ, DDR4, DIMM, 2666 МГц
# 123       16 ГБ, DDR4, DIMM, 3200 МГц
# 124        8 ГБ, DDR4, DIMM, 3200 МГц
# 125       16 ГБ, DDR4, DIMM, 3200 МГц
# 126        8 ГБ, DDR4, DIMM, 3200 МГц
# 127        8 ГБ, DDR4, DIMM, 3200 МГц
# 128       16 ГБ, DDR4, DIMM, 3200 МГц
# 129       16 ГБ, DDR4, DIMM, 3200 МГц
# 130     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 131       16 ГБ, DDR4, DIMM, 3200 МГц
# 132       16 ГБ, DDR4, DIMM, 3200 МГц
# 133        8 ГБ, DDR4, DIMM, 3200 МГц
# 134        8 ГБ, DDR4, DIMM, 3200 МГц
# 135        8 ГБ, DDR4, DIMM, 3200 МГц
# 136        8 ГБ, DDR4, DIMM, 3200 МГц
# 137       16 ГБ, DDR4, DIMM, 3200 МГц
# 138        8 ГБ, DDR4, DIMM, 3200 МГц
# 139        8 ГБ, DDR4, DIMM, 3200 МГц
# 140        8 ГБ, DDR4, DIMM, 3200 МГц
# 141       16 ГБ, DDR4, DIMM, 3200 МГц
# 142        8 ГБ, DDR4, DIMM, 3200 МГц
# 143     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 144       16 ГБ, DDR4, DIMM, 3200 МГц
# 145       16 ГБ, DDR4, DIMM, 3200 МГц
# 146       16 ГБ, DDR4, DIMM, 3200 МГц
# 147        8 ГБ, DDR4, DIMM, 3200 МГц
# 148       16 ГБ, DDR4, DIMM, 3200 МГц
# 149        8 ГБ, DDR4, DIMM, 3200 МГц
# 150        8 ГБ, DDR4, DIMM, 3200 МГц
# 151       16 ГБ, DDR5, DIMM, 4800 МГц
# 152       16 ГБ, DDR4, DIMM, 3200 МГц
# 153       16 ГБ, DDR4, DIMM, 3200 МГц
# 154       16 ГБ, DDR4, DIMM, 3200 МГц
# 155        8 ГБ, DDR4, DIMM, 3200 МГц
# 156    32 ГБ, DDR5, SO-DIMM, 4800 МГц
# 157       16 ГБ, DDR4, DIMM, 3200 МГц
# 158        8 ГБ, DDR4, DIMM, 3200 МГц
# 159       16 ГБ, DDR4, DIMM, 3200 МГц
# 160        8 ГБ, DDR4, DIMM, 3200 МГц
# 161        8 ГБ, DDR4, DIMM, 2666 МГц
# 162     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 163    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 164     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 165    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 166    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 167     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 168    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 169    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 170       16 ГБ, DDR4, DIMM, 2666 МГц
# 171        8 ГБ, DDR4, DIMM, 2666 МГц
# 172                         , SO-DIMM
# 173    16 ГБ, DDR4, SO-DIMM, 2933 МГц
# 174       16 ГБ, DDR4, DIMM, 2666 МГц
# 175       16 ГБ, DDR4, DIMM, 3200 МГц
# 176       8 ГБ, DDR4, UDIMM, 3200 МГц
# 177     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 178     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 179    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 180        8 ГБ, DDR4, DIMM, 3200 МГц
# 181        8 ГБ, DDR4, DIMM, 3200 МГц
# 182        8 ГБ, DDR4, DIMM, 3200 МГц
# 183       16 ГБ, DDR4, DIMM, 3200 МГц
# 184       16 ГБ, DDR4, DIMM, 3200 МГц
# 185       16 ГБ, DDR4, DIMM, 2666 МГц
# 186        8 ГБ, DDR4, DIMM, 2666 МГц
# 187        8 ГБ, DDR4, DIMM, 2666 МГц
# 188     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 189       16 ГБ, DDR4, DIMM, 2666 МГц
# 190    16 ГБ, DDR4, SO-DIMM, 3200 МГц
# 191        8 ГБ, DDR4, DIMM, 2666 МГц
# 192                                 0
# 193     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 194       8 ГБ, DDR4, UDIMM, 3200 МГц
# 195       16 ГБ, DDR4, DIMM, 3200 МГц
# 196       16 ГБ, DDR4, DIMM, 3200 МГц
# 197       16 ГБ, DDR4, DIMM, 3200 МГц
# 198       16 ГБ, DDR4, DIMM, 3200 МГц
# 199        8 ГБ, DDR4, DIMM, 2666 МГц
# 200       16 ГБ, DDR4, DIMM, 3200 МГц
# 201        8 ГБ, DDR4, DIMM, 3200 МГц
# 202        8 ГБ, DDR4, DIMM, 2666 МГц
# 203     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 204                   , DDR4, SO-DIMM
# 205     8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 206     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 207       32 ГБ, DDR4, DIMM, 3200 МГц
# 208       16 ГБ, DDR4, DIMM, 3200 МГц
# 209       16 ГБ, DDR4, DIMM, 2666 МГц
# 210       16 ГБ, DDR4, DIMM, 2666 МГц
# 211       16 ГБ, DDR4, DIMM, 2666 МГц
# 212        8 ГБ, DDR4, DIMM, 2666 МГц
# 213        8 ГБ, DDR4, DIMM, 2666 МГц
# 214       16 ГБ, DDR4, DIMM, 2666 МГц
# 215                                 0
# 216        8 ГБ, DDR4, DIMM, 2666 МГц
# 217       16 ГБ, DDR4, DIMM, 3200 МГц
# 218        8 ГБ, DDR4, DIMM, 3200 МГц
# 219       16 ГБ, DDR4, DIMM, 3200 МГц
# 220       16 ГБ, DDR4, DIMM, 3200 МГц
# 221       16 ГБ, DDR4, DIMM, 3200 МГц
# 222        8 ГБ, DDR4, DIMM, 3200 МГц
# 223        8 ГБ, DDR4, DIMM, 3200 МГц
# 224        8 ГБ, DDR4, DIMM, 3200 МГц
# 225        8 ГБ, DDR4, DIMM, 3200 МГц
# 226        8 ГБ, DDR4, DIMM, 3200 МГц
# 227        8 ГБ, DDR4, DIMM, 3200 МГц
# 228       16 ГБ, DDR4, DIMM, 3200 МГц
# 229        8 ГБ, DDR4, DIMM, 3200 МГц
# 230        8 ГБ, DDR4, DIMM, 2666 МГц
# 231        8 ГБ, DDR4, DIMM, 3200 МГц
# 232       16 ГБ, DDR4, DIMM, 3200 МГц
# 233       16 ГБ, DDR4, DIMM, 3200 МГц
# 234       16 ГБ, DDR4, DIMM, 3200 МГц
# 235       16 ГБ, DDR4, DIMM, 3200 МГц
# 236        8 ГБ, DDR4, DIMM, 3200 МГц
# 237       16 ГБ, DDR4, DIMM, 2666 МГц
# 238       16 ГБ, DDR4, DIMM, 3200 МГц
# 239        8 ГБ, DDR4, DIMM, 2666 МГц
# 240     8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 241              8 ГБ, DDR4, 3200 МГц
# 242              8 ГБ, DDR4, 3200 МГц
# 243              8 ГБ, DDR4, 3200 МГц
# 244              8 ГБ, DDR4, 3200 МГц
# 245       16 ГБ, DDR4, DIMM, 3200 МГц
# 246       16 ГБ, DDR4, DIMM, 2666 МГц
# 247        8 ГБ, DDR4, DIMM, 2666 МГц
# 248        8 ГБ, DDR4, DIMM, 2666 МГц
# 249     8 ГБ, DDR4, SO-DIMM, 3200 МГц
# 250        8 ГБ, DDR4, DIMM, 3200 МГц
# 251        8 ГБ, DDR4, DIMM, 2666 МГц
# 252       16 ГБ, DDR4, DIMM, 2666 МГц
# 253        8 ГБ, DDR4, DIMM, 2666 МГц
# 254       16 ГБ, DDR4, DIMM, 2666 МГц
# 255        8 ГБ, DDR4, DIMM, 2666 МГц
# 256                  8 ГБ, DDR4, DIMM
# 257                 16 ГБ, DDR4, DIMM
# 258        8 ГБ, DDR4, DIMM, 3200 МГц
# 259              8 ГБ, DDR4, 2666 МГц
# 260       16 ГБ, DDR4, DIMM, 2666 МГц
# 261       16 ГБ, DDR4, DIMM, 2666 МГц
# 262        8 ГБ, DDR4, DIMM, 2666 МГц
# 263        8 ГБ, DDR4, DIMM, 2666 МГц
# 264       8 ГБ, DDR4, UDIMM, 3200 МГц
# 265       8 ГБ, DDR4, UDIMM, 3200 МГц
# 266     4 ГБ, DDR4, SO-DIMM, 3200 МГц
# 267       32 ГБ, DDR4, DIMM, 3200 МГц
# 268       32 ГБ, DDR4, DIMM, 3200 МГц
# 269        8 ГБ, DDR4, DIMM, 3200 МГц
# 270       16 ГБ, DDR4, DIMM, 3200 МГц
# 271       16 ГБ, DDR4, DIMM, 3200 МГц
# 272        8 ГБ, DDR4, DIMM, 2666 МГц
# 273        8 ГБ, DDR4, DIMM, 2666 МГц
# 274        8 ГБ, DDR4, DIMM, 2666 МГц
# 275                        4 ГБ, DDR3
# 276        8 ГБ, DDR4, DIMM, 2666 МГц
# 277       32 ГБ, DDR4, DIMM, 2666 МГц
# 278       8 ГБ, DDR4, UDIMM, 2933 МГц
# 279       8 ГБ, DDR4, UDIMM, 2666 МГц
# 280        8 ГБ, DDR4, DIMM, 3200 МГц
# 281        8 ГБ, DDR4, DIMM, 3200 МГц
# 282        8 ГБ, DDR4, DIMM, 2666 МГц
# 283        8 ГБ, DDR4, DIMM, 2666 МГц
# 284        8 ГБ, DDR4, DIMM, 2666 МГц
# 285        8 ГБ, DDR4, DIMM, 2666 МГц
# 286        8 ГБ, DDR4, DIMM, 2666 МГц
# 287       16 ГБ, DDR4, DIMM, 2666 МГц
# 288       16 ГБ, DDR4, DIMM, 3200 МГц
# 289        8 ГБ, DDR4, DIMM, 3200 МГц
# 290        8 ГБ, DDR4, DIMM, 2666 МГц
# 291       16 ГБ, DDR4, DIMM, 2666 МГц
# 292       16 ГБ, DDR4, DIMM, 3000 МГц
# 293     8 ГБ, DDR4, SO-DIMM, 2933 МГц
# 294     8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 295     8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 296       16 ГБ, DDR4, DIMM, 3000 МГц
# 297        8 ГБ, DDR4, DIMM, 2666 МГц
# 298     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 299       16 ГБ, DDR4, DIMM, 2666 МГц
# 300                              8 ГБ
# 301       16 ГБ, DDR4, DIMM, 2666 МГц
# 302     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 303     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 304     4 ГБ, DDR4, SO-DIMM, 2666 МГц
# 305        8 ГБ, DDR4, DIMM, 2666 МГц
# 306        8 ГБ, DDR4, DIMM, 2666 МГц
# 307                                 0
# 308                         8 ГБ, DDR
# 309       16 ГБ, DDR4, DIMM, 3000 МГц
# 310       16 ГБ, DDR4, DIMM, 3000 МГц
# 311       16 ГБ, DDR4, DIMM, 3000 МГц
# 312       16 ГБ, DDR4, DIMM, 3000 МГц
# 313       16 ГБ, DDR4, DIMM, 3000 МГц
# 314       16 ГБ, DDR4, DIMM, 3000 МГц
# 315       16 ГБ, DDR4, DIMM, 3000 МГц
# 316       16 ГБ, DDR4, DIMM, 3000 МГц
# 317       16 ГБ, DDR4, DIMM, 3000 МГц
# 318        8 ГБ, DDR4, DIMM, 3000 МГц
# 319       16 ГБ, DDR4, DIMM, 3000 МГц
# 320       16 ГБ, DDR4, DIMM, 3000 МГц
# 321        8 ГБ, DDR4, DIMM, 3000 МГц
# 322        8 ГБ, DDR4, DIMM, 3000 МГц
# 323        8 ГБ, DDR4, DIMM, 3000 МГц
# 324                 16 ГБ, DDR4, DIMM
# 325                 16 ГБ, DDR4, DIMM
# 326        8 ГБ, DDR4, DIMM, 2400 МГц
# 327       32 ГБ, DDR5, DIMM, 4400 МГц
# 328       16 ГБ, DDR4, DIMM, 2666 МГц
# 329       16 ГБ, DDR4, DIMM, 2666 МГц
# 330                 16 ГБ, DDR4, DIMM
# 331       16 ГБ, DDR4, DIMM, 3000 МГц
# 332       16 ГБ, DDR4, DIMM, 2666 МГц
# 333       16 ГБ, DDR4, DIMM, 3000 МГц
# 334       16 ГБ, DDR4, DIMM, 3000 МГц
# 335        8 ГБ, DDR4, DIMM, 3200 МГц
# 336       16 ГБ, DDR4, DIMM, 3000 МГц
# 337       16 ГБ, DDR4, DIMM, 3000 МГц
# 338       32 ГБ, DDR4, DIMM, 3000 МГц
# 339        8 ГБ, DDR4, DIMM, 2933 МГц
# 340       16 ГБ, DDR4, DIMM, 2400 МГц
# 341        8 ГБ, DDR4, DIMM, 2666 МГц
# 342        8 ГБ, DDR4, DIMM, 2666 МГц
# 343       16 ГБ, DDR4, DIMM, 3200 МГц
# 344       16 ГБ, DDR4, DIMM, 3000 МГц
# 345        4 ГБ, DDR4, DIMM, 2666 МГц
# 346                 32 ГБ, DDR4, DIMM
# 347                  8 ГБ, DDR4, DIMM
# 348                  8 ГБ, DDR4, DIMM
# 349                  8 ГБ, DDR4, DIMM
# 350                  8 ГБ, DDR4, DIMM
# 351                  8 ГБ, DDR4, DIMM
# 352                 16 ГБ, DDR4, DIMM
# 353                  8 ГБ, DDR4, DIMM
# 354                 16 ГБ, DDR4, DIMM
# 355                 16 ГБ, DDR4, DIMM
# 356                  8 ГБ, DDR4, DIMM
# 357                  8 ГБ, DDR4, DIMM
# 358                  8 ГБ, DDR4, DIMM
# 359                  8 ГБ, DDR4, DIMM
# 360                  8 ГБ, DDR4, DIMM
# 361                  8 ГБ, DDR4, DIMM
# 362                  8 ГБ, DDR4, DIMM
# 363        8 ГБ, DDR4, DIMM, 2400 МГц
# 364                  8 ГБ, DDR4, DIMM
# 365      16 ГБ, DDR4, UDIMM, 3200 МГц
# 366                  8 ГБ, DDR4, DIMM
# 367                  8 ГБ, DDR4, DIMM
# 368       32 ГБ, DDR4, DIMM, 3000 МГц
# 369                  8 ГБ, DDR4, DIMM
# 370       16 ГБ, DDR4, DIMM, 3000 МГц
# 371       32 ГБ, DDR4, DIMM, 3000 МГц
# 372       16 ГБ, DDR4, DIMM, 3200 МГц
# 373       16 ГБ, DDR4, DIMM, 3000 МГц
# 374        4 ГБ, DDR4, DIMM, 2666 МГц
# 375       16 ГБ, DDR4, DIMM, 2400 МГц
# 376       16 ГБ, DDR4, DIMM, 2400 МГц
# 377       16 ГБ, DDR4, DIMM, 2400 МГц
# 378        4 ГБ, DDR4, DIMM, 2666 МГц
# 379                                 0
# 380                                 0
# 381                             16 ГБ
# 382                                 0
# 383                                 0
# 384       32 ГБ, DDR4, DIMM, 3200 МГц
# 385       32 ГБ, DDR4, DIMM, 3200 МГц
# 386       16 ГБ, DDR4, DIMM, 3200 МГц
# 387       32 ГБ, DDR4, DIMM, 3200 МГц
# 388       16 ГБ, DDR4, DIMM, 3200 МГц
# 389       16 ГБ, DDR4, DIMM, 3200 МГц
# 390                                 0
# 391       16 ГБ, DDR4, DIMM, 2666 МГц
# 392        8 ГБ, DDR4, DIMM, 2666 МГц
# 393                                 0
# 394                                 0
# 395                                 0
# 396        8 ГБ, DDR4, DIMM, 3200 МГц
# 397       16 ГБ, DDR4, DIMM, 3200 МГц
# 398       16 ГБ, DDR4, DIMM, 3200 МГц
# 399       16 ГБ, DDR4, DIMM, 3200 МГц
# 400       16 ГБ, DDR4, DIMM, 3200 МГц
# 401        8 ГБ, DDR4, DIMM, 3200 МГц
# 402        8 ГБ, DDR4, DIMM, 3200 МГц
# 403                                 0
# 404       16 ГБ, DDR4, DIMM, 2666 МГц
# 405                                 0
# 406        8 ГБ, DDR4, DIMM, 2666 МГц
# 407                                 0
# 408     8 ГБ, DDR4, SO-DIMM, 2666 МГц
# 409       16 ГБ, DDR4, DIMM, 3200 МГц
# 410       16 ГБ, DDR4, DIMM, 2666 МГц
# 411        8 ГБ, DDR4, DIMM, 2666 МГц
# 412        8 ГБ, DDR4, DIMM, 2666 МГц
# 413                                 0
# 414                                 0
# 415                                 0
# 416        8 ГБ, DDR4, DIMM, 2666 МГц
# 417                                 0
# 418                                 0
# 419                                 0
# 420        8 ГБ, DDR4, DIMM, 2666 МГц
# 421                                 0
# 422                                 0
# 423                                 0
# 424                                 0
# 425                                 0
# 426                                 0
# 427                                 0
# Name: Оперативная память, dtype: object

# %%
df2['Модель процессора']
# Out:
# 0           Core i5-12400
# 1           Core i5-12400
# 2           Ryzen 5 5600X
# 3          Core i5-11400F
# 4           Core i3-10105
# 5        Ryzen 5 Pro 3600
# 6          Core i5-11400F
# 7          Core i5-12400F
# 8          Core i5-11400F
# 9          Core i5-11400F
# 10         Core i5-11400F
# 11         Core i5-11400F
# 12           Ryzen 5 3600
# 13           Athlon 3050U
# 14          Ryzen 3 3250U
# 15               A4-9120e
# 16          Core i5-12400
# 17          Core i5-12400
# 18          Core i5-10400
# 19         Core i5-11400F
# 20         Core i5-11400F
# 21          Ryzen 5 5600G
# 22          Core i5-11400
# 23         Core i5-10400F
# 24           Ryzen 5 3600
# 25         Core i5-11400F
# 26         Core i5-10400F
# 27         Core i3-10105F
# 28         Core i5-11400F
# 29          Ryzen 5 3400G
# 418         Ryzen 5 5600G
# 419         Core i5-11400
# 420          Core i5-9400
# 421     Ryzen 5 Pro 3400G
# 422    Pentium Gold G6400
# 423    Pentium Gold G6405
# 424    Pentium Gold G6405
# 425         Core i3-10105
# 426        Core i7-11700F
# 427        Core i5-12400F
# 428        Core i7-12700F
# 429                     0
# 430        Core i7-11700K
# 431        Core i7-11700F
# 432        Core i9-12900K
# 433        Core i7-12700F
# 434        Core i7-12700F
# 435       Core i7-12700KF
# 436       Core i7-12700KF
# 437       Core i7-12700KF
# 438       Core i7-12700KF
# 439        Core i7-12700F
# 440        Core i7-12700F
# 441        Core i5-12400F
# 442        Core i7-12700F
# 443        Core i7-12700F
# 444        Core i7-12700F
# 445        Core i7-12700F
# 446        Core i5-12400F
# 447        Core i7-12700F
# 448         Ryzen 9 5900X
# 449                     0
# 450       Core i7-12700KF
# 451        Core i5-12400F
# 452       Core i7-12700KF
# 453       Core i7-12700KF
# 454       Core i7-12700KF
# 455        Core i7-12700F
# 456       Core i7-13700KF
# 457       Core i9-12900KF
# 458        Core i7-12700F
# 459       Core i7-12700KF
# 460        Core i5-12400F
# 461        Core i7-12400F
# 462         Ryzen 9 7900X
# 463                     0
# 464        Core i5-12400F
# 465        Core i5-12600K
# 466         Ryzen 5 7600X
# 467         Ryzen 7 7700X
# 468         Ryzen 7 5700G
# 469         Ryzen 5 5600G
# 470        Core i5-11400F
# 471         Ryzen 5 5600G
# 472         Ryzen 7 5700G
# 473        Core i5-11400F
# 474                     0
# 475         Ryzen 5 3400G
# 476        Core i5-12400F
# 477        Core i5-12400F
# 478         Ryzen 5 5600G
# 479       Core i7-13700KF
# 480                     0
# 481       Core i7-12700KF
# 482                     0
# 483        Core i5-12400F
# 484        Core i7-12700F
# 485         Ryzen 5 7600X
# 486        Core i5-12400F
# 487        Core i7-12700F
# 488        Core i7-12700F
# 489        Core i5-12400F
# 490        Core i5-12400F
# 491       Core i7-13700KF
# 492       Core i7-13700KF
# 493       Core i9-13900KF
# 494         Ryzen 9 7950X
# 495         Ryzen 9 7950X
# 496        Core i5-12400F
# 497        Core i7-12700F
# 498        Core i7-12700F
# 499        Core i5-12400F
# Name: Модель процессора, dtype: object

# %%
set(columns1)
# Out:
# {'link',
#  'Блок питания',
#  'Бренд',
#  'Буферная память HDD',
#  'Вес товара',
#  'Вес упаковки (ед)',
#  'Возможность монтажа в стойку',
#  'Время отклика',
#  'Встроенные динамики',
#  'Входное напряжение (макс)',
#  'Входное напряжение (мин)',
#  'Габариты упаковки (ед) ДхШхВ',
#  'Гарантийное',
#  'Гарантия',
#  'Графика',
#  'Диагональ экрана',
#  'Дополнительно в комплекте',
#  'Жесткий диск',
#  'Кард-ридер',
#  'Клавиатура',
#  'Клавиатура с русскими буквами',
#  'Количество высокопроизводительных ядер',
#  'Количество отзывов',
#  'Количество энергоэффективных ядер',
#  'Количество ядер процессора',
#  'Комплектация',
#  'Максимальный объем оперативной памяти',
#  'Модель монитора',
#  'Монитор в комплекте',
#  'Мышь',
#  'Название',
#  'Объем SSD',
#  'Объем второго SSD',
#  'Оперативная память',
#  'Операционная система',
#  'Оптический привод',
#  'Особенности',
#  'Особенности ОС',
#  'Особенности графического контроллера',
#  'Особенности жестких дисков',
#  'Особенности оперативной памяти',
#  'Особенности процессора',
#  'Отделка корпуса',
#  'Поддержка Bluetooth',
#  'Поддержка Intel Optane',
#  'Поддержка Wi-Fi',
#  'Поддержка карт памяти',
#  'Процессор',
#  'Процессор, частота',
#  'Размер крепления VESA',
#  'Размеры корпуса (ШхВхГ)',
#  'Разрешение экрана',
#  'Разрядность ОС',
#  'Разъем для микрофона',
#  'Разъем для наушников',
#  'Разъем наушники/микрофон',
#  'Разъемов D-Sub',
#  'Разъемов DVI',
#  'Разъемов DisplayPort',
#  'Разъемов HDMI',
#  'Разъемов PS/2',
#  'Разъемов RS-232',
#  'Разъемов Thunderbolt 3',
#  'Разъемов Thunderbolt 4',
#  'Разъемов USB 2.0',
#  'Разъемов USB 2.0 (Type-C)',
#  'Разъемов USB 3.0',
#  'Разъемов USB 3.0 (Type-C)',
#  'Разъемов USB 3.1',
#  'Разъемов USB 3.1 (Type-C)',
#  'Разъемов USB 3.2 (Type-C)',
#  'Разъемов USB 4.0',
#  'Рейтинг',
#  'Сокет процессора',
#  'Стандарт Bluetooth',
#  'Стандарт Wi-Fi',
#  'Страна производства',
#  'Тип блока питания',
#  'Тип вилки',
#  'Тип графического контроллера',
#  'Тип кабельной сети (разъем RJ-45)',
#  'Тип корпуса',
#  'Угол обзора',
#  'Цвет корпуса',
#  'Цена',
#  'Частота электросети',
#  'Частота энергоэффективных ядер',
#  'Чипсет материнской платы',
#  'Число ядер GPU',
#  'Экран с поддержкой 3D',
#  'Яркость экрана'}

# %%
set(columns2)
# Out:
# {'Bluetooth-адаптер',
#  'DVI',
#  'DisplayPort',
#  'HDMI',
#  'LAN разъем (RJ-45)',
#  'LAN-адаптер',
#  'Line-In',
#  'PS/2',
#  'Speaker-Out',
#  'Thunderbolt 3',
#  'Thunderbolt/USB 4',
#  'Toslink',
#  'USB',
#  'USB 2.0',
#  'USB 3.0',
#  'USB 3.0 (Type-C)',
#  'USB 3.1',
#  'USB 3.1 (Type-C)',
#  'USB 3.2',
#  'USB 3.2 (Type-C)',
#  'VGA (D-Sub)',
#  'Wi-Fi',
#  'link',
#  'Вес',
#  'Высота',
#  'Гарантия',
#  'Глубина',
#  'Дополнительная информация',
#  'Звуковая карта',
#  'Игровой системный блок',
#  'Интерфейс подключения',
#  'Кабель питания',
#  'Картридер',
#  'Клавиатура',
#  'Количество отзывов',
#  'Количество ядер',
#  'Количество ядер графического процессора',
#  'Кэш L2',
#  'Кэш L3',
#  'Максимальная тактовая частота',
#  'Максимальный объем',
#  'Материал корпуса',
#  'Модель видеокарты',
#  'Модель процессора',
#  'Модель чипсета',
#  'Мощность блока питания',
#  'Мышь',
#  'Название',
#  'Объем видеопамяти',
#  'Объем второго накопителя',
#  'Объем накопителя',
#  'Объем оперативной памяти',
#  'Объем первого накопителя',
#  'Операционная система',
#  'Подсветка корпуса',
#  'Последовательный порт RS-232',
#  'Производитель видеокарты',
#  'Производитель процессора',
#  'Производитель чипсета',
#  'Размещение',
#  'Разрядность',
#  'Разъем для микрофона',
#  'Разъем для наушников',
#  'Разъем для наушников/микрофона',
#  'Рейтинг',
#  'Скорость вращения шпинделя',
#  'Слоты для оперативной памяти',
#  'Стандарт Wi-Fi',
#  'Страна',
#  'Тактовая частота',
#  'Тип видеокарты',
#  'Тип видеопамяти',
#  'Тип вилки',
#  'Тип накопителя',
#  'Тип оперативной памяти',
#  'Тип оптического привода',
#  'Типоразмер корпуса',
#  'Фронтальный разъем для микрофона 3.5мм',
#  'Фронтальный разъем для наушников 3.5мм',
#  'Фронтальный разъем для наушников/микрофона 3.5мм',
#  'Цвет',
#  'Цена',
#  'Частота памяти',
#  'Ширина'}

# %%
name_old = 'Количество ядер процессора'
name_new = 'Количество ядер'
df1.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Модель процессора'
name_new = 'Процессор'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
 
name_old = 'Объем накопителя'
name_new = 'Объем SSD'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Модель видеокарты'
name_new = 'Графика'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Количество потоков'
name_new = 'Максимальное число потоков'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Мощность блока питания'
name_new = 'Блок питания'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Количество слотов'
name_new = 'Количество слотов оперативной'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Картридер'
name_new = 'Кард-ридер'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Web-камера'
name_new = 'Веб-камера'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'USB 2.0 (Type-C)'
name_new = 'Порты USB 2.1 (Type-C)'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Оперативная память'
name_new = 'Объем оперативной памяти'
df1.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'USB 3.0 (Type-C)'
name_new = 'Порты USB 3.0 (Type-C)'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'USB 3.1 (Type-C)'
name_new = 'Порты USB 3.1 (Type-C)'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'USB 3.2 (Type-C)'
name_new = 'Порты USB 3.2 (Type-C)'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Мощность блока питания'
name_new = 'Выходная мощность адаптера питания'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Диагональ экрана в'
name_new = 'Диагональ экрана'
df1.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Технология динамического экрана'
name_new = 'Динамический экран'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
name_old = 'Игровой ноутбук'
name_new = 'Для геймеров'
df2.rename(columns={name_old: name_new}, inplace=True)

# %%
df1 = df1.fillna(0)
df2 = df2.fillna(0)

# %%
column = set(df1.columns) & set(df2.columns)

df_full = df1.loc[:, column]

df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Процессор                 428 non-null    object
#  1   Гарантия                  428 non-null    object
#  2   Объем SSD                 428 non-null    object
#  3   Кард-ридер                428 non-null    object
#  4   Мышь                      428 non-null    object
#  5   Цена                      428 non-null    object
#  6   Количество ядер           428 non-null    object
#  7   Стандарт Wi-Fi            428 non-null    object
#  8   Количество отзывов        428 non-null    float64
#  9   Название                  428 non-null    object
#  10  Операционная система      428 non-null    object
#  11  Клавиатура                428 non-null    object
#  12  link                      428 non-null    object
#  13  Рейтинг                   428 non-null    object
#  14  Блок питания              428 non-null    object
#  15  Разъем для наушников      428 non-null    float64
#  16  Графика                   428 non-null    object
#  17  Объем оперативной памяти  428 non-null    object
#  18  Разъем для микрофона      428 non-null    float64
#  19  Тип вилки                 428 non-null    object
# dtypes: float64(3), object(17)
# memory usage: 67.0+ KB
# C:\Users\ilya\AppData\Local\Temp\ipykernel_11888\3155891446.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_full = df1.loc[:, column]

# %%
column = 'Блок питания'

# %%
def func(s):
    try:
        if " Вт" in s:
          return float(s.replace(" Вт", ""))
        
        return s
        
    except Exception:
        pass



df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [ 650.  400.  500.  330.   nan  700.  300.   65.  120.   90.  750.  100.
#   550.  800.  350.  180.  280.  260.  450.  135.  850.  310.  380.  600.
#   230.  250. 1000.]
# [ 300.  600.   nan  800.  500.  700.  180.   90.   65.  400.  550.  450.
#   650. 1000.  750.  185. 1200.   19.  696.  260.  850.  150.  200. 1650.
#   380.  310.  370.  230.  120.  350.]

# %%
column = 'Цена'

# %%
def func(s):
    try:
        if "Нет в наличии" in s:
            return 0.0
        elif "₽" in s:
            return float(s.replace("₽", "").replace(" ", "").replace(",", "."))
        elif "р." in s:
            return int(s.replace("р.", "").replace(" ", ""))
        else:
            return int(s.replace(" ", ""))
 
    except Exception:
        pass



df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
column = 'Операционная система'

df1[column] = df1[column].str.lower()
df2[column] = df2[column].str.lower()

# %%
def func(s):
    try:
        if s == 0:
            return 0.0
        if "macos" in s:
            return "mac"
        elif " " in s:
            return s.split(" ")[0]
        else:
            return s
    except Exception:
        pass
df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
combined_column = pd.concat([df1[column], df2[column]])


label_encoder.fit(combined_column.astype(str))


df1[column] = label_encoder.transform(df1[column].astype(str))
df2[column] = label_encoder.transform(df2[column].astype(str))

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [3 7 6 8 5 2]
# [9 4 8 6 1 5]

# %%
column = 'Объем оперативной памяти'

# %%
def func(s):
    try:
        if s == 0:
            return 0.0
        if " ГБ" in s:
            return float(s.split(" ГБ")[0])
        else:
            return 0.0
    except Exception:
        pass
df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [16.  8.  4. 32. 12.]
# [ 16.  32.   8.   4.  64. 128.]

# %%
column = 'Количество ядер'

# %%
def func(s):
    try:
        if s == 0:
            return 0.0
        
        if "-ядерный" in s:
            return float(s.split("-ядерный")[0])
        else:
            return float(s)

    except Exception:
        pass



df1[column] = df1[column].apply(func)

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [ 6.  4.  2.  8. 12. 10. 16.]
# [ 6.  4.  2.  8. 12. 10. 16. 24. 14.]

# %%
column = 'Рейтинг'

# %%
def func(s):
    try:
        if s == 0:
            return 0.0
        
        if "Код товара" in s:
            return 0.0
        elif "Обзор" in s:
            return float(s.split(" Обзор")[0])
        else:
            return float(s)

    except Exception:
        pass



df1[column] = df1[column].apply(func)

# %%
print(df2[column][df2[column] != 0 ].unique())
print(df1[column][df1[column] != 0 ].unique())
# Out:
# [5. 4. 1.]
# [4.8 4.7 5.  4.6 4.5 3.8 3.  4.  4.3 1. ]

# %%
column = 'Гарантия'

# %%
def func(s):
    try :
        if s == 0:
            return 0.0
        elif "год" in s:
            return int(s.split(" ")[0])* 12
        elif "мес." in s:
            return int(s.split(" ")[0])


    except Exception:
        pass

df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
print(df2[column][df2[column] != 0 ].unique())
print(df1[column][df1[column] != 0 ].unique())
# Out:
# [12. nan 36. 24.]
# [36. 12.]

# %%
column = 'Графика'

df1[column] = df1[column].str.lower()
df2[column] = df2[column].str.lower()

# %%
def func(s):
    try:
        if "nvidia" in s:
            return s.split(" - ")[0].replace("nvidia ", "")
        else:
            return s
    except Exception:
        pass

df1[column] = df1[column].apply(func)

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()


combined_column = pd.concat([df1[column], df2[column]])


label_encoder.fit(combined_column.astype(str))


df1[column] = label_encoder.transform(df1[column].astype(str))
df2[column] = label_encoder.transform(df2[column].astype(str))

# %%
df1[column][df1[column] != 0 ].unique()
# Out:
# array([25, 49,  1, 24, 27, 19, 16, 48, 51,  2, 11, 46, 15, 42, 30, 47, 52,
#         7, 18, 53, 31, 43,  4, 28, 14, 12, 50, 71, 45, 21, 33, 44,  3,  6,
#        23,  8,  5, 36, 37])

# %%
df2[column][df2[column] != 0 ].unique()
# Out:
# array([16, 25, 68, 41, 28, 67, 66, 65, 57, 56, 58, 24, 76, 22, 60, 74, 59,
#        19, 26,  2, 77, 29, 55, 31, 33, 10, 62, 38, 54, 70, 64, 35, 34, 36,
#        32,  9, 49, 20, 61, 17, 40, 13, 72, 73, 37, 63, 75, 69, 39])

# %%
column = 'Название'

df1[column] = df1[column].str.lower()
df2[column] = df2[column].str.lower()

# %%
def func(s):
    try:
        if "," in s:
            return s.split(",")[0]
        elif "/" in s:
            return s.split("/")[0]
        else:
            return s
    except Exception:
        pass



df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
df1[column][df1[column] != 0 ].head(10)
# Out:
# 0              компьютер iru game 310h5gma
# 1               компьютер iru home 310h5se
# 2               компьютер iru game 310h5gs
# 3               компьютер iru home 310h5se
# 4                                        ‌
# 5        компьютер hp pavilion tg01-2017ur
# 6    компьютер msi creator p50 11si-232xru
# 7      компьютер msi infinite 11si-1611xru
# 8      компьютер msi infinite 11th-1610xru
# 9            компьютер acer aspire tc-1660
# Name: Название, dtype: object

# %%
df2[column][df2[column] != 0 ].head(10)
# Out:
# 0       игровой компьютер thunderobot alpha d i5-12400
# 1    игровой компьютер thunderobot bw iii pro xl d ...
# 2    игровой компьютер asus rog g15 tower dt g15dk-...
# 3                          компьютер must mbm114003070
# 4                       компьютер iru 310h5ge i3 10105
# 5                 игровой компьютер must mbm3600110722
# 6    игровой компьютер acer predator orion 3000 po3...
# 7       компьютер acer nitro 50 n50-640 (dg.e2ver.003)
# 8    игровой компьютер acer aspire tc-1660 dg.bgzer...
# 9        игровой компьютер acer tc-1660 (dg.bgzer.010)
# Name: Название, dtype: object

# %%
column = 'Объем SSD'

# %%
def func(s):
    try:
        if s == 0:
            return 0.0
        if " ГБ" in s:
            return float(s.split(" ГБ")[0])
        elif " ТБ" in s:
            return float(s.split(" ТБ "))
        else:
            return s
    except Exception:
        pass
df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [1024.  240.  512.  256.  500.  250.  480. 1000.  128.  120.]
# [ 512.   nan  256.  500.  480.  960. 1512. 1480. 2512.  240. 1500. 1256.
#   128.]

# %%
column = 'Мышь'

# %%
def func(s):
    try:
        if "в комплекте" in s:
            return 1
        else:
            return s
    except Exception:
        pass

df1[column] = df1[column].apply(func)

# %%
print(df1[column].unique())
print(df2[column].unique())
# Out:
# [nan  1.]
# [0. 1.]

# %%
column = 'Клавиатура'

# %%
def func(s):
    try:
        if "в комплекте" in s:
            return 1
        else:
            return s
    except Exception:
        pass

df1[column] = df1[column].apply(func)

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [nan  1.]
# [1.]

# %%
column = 'Процессор'

df1[column] = df1[column].str.lower()
df2[column] = df2[column].str.lower()

# %%
def func(s):
    try:
        if "amd " in s:
            return s.replace("amd ryzen ", "")
        elif "intel " in s:
            return s.replace("intel ", "")[5:-1].replace(" ", "-")
        elif "core" in s:
            return s.replace("core ", "")
        elif "ryzen" in s:
            return s.replace("ryzen ", "")
        else:
            return s
    except Exception:
        pass

df1[column] = df1[column].apply(func)
df2[column] = df2[column].apply(func)

# %%
combined_column = pd.concat([df1[column], df2[column]])


label_encoder.fit(combined_column.astype(str))


df1[column] = label_encoder.transform(df1[column].astype(str))
df2[column] = label_encoder.transform(df2[column].astype(str))

# %%
print(df1[column][df1[column] != 0 ].unique())
print(df2[column][df2[column] != 0 ].unique())
# Out:
# [ 50  34  25  56  49 104   4  97  19  45  69  29   9  73  98  55  72  27
#   37  12   8  80  22  31  20  42 100  16  62  40  44  59  61  53  58  79
#  105  11 106  86  84  78  54  85  71  47  43  41  70  35  90 107  48   3
#   99  67   5  82  89   7  18  10   2   6 103  87  39]
# [ 56  12  51  37  15  57   8  33   1  26  45  11  50  46  38   7  74  76
#   10  36  35  83  25  81  32  88  95  65  20  80  19  86  63  91  64  93
#   30  66  92  17  87  94  28  52  68  14 101 102  75  22  77  23  60  13
#   21  96  24]

# %%
print(len(df1[column][df1[column] != 0 ].unique()))
print(len(df2[column][df2[column] != 0 ].unique()))
# Out:
# 67
# 57

# %%
column = set(df1.columns) & set(df2.columns)

df_full = df1.loc[:, column]

df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Процессор                 428 non-null    int32
#  1   Гарантия                  428 non-null    float64
#  2   Объем SSD                 428 non-null    float64
#  3   Кард-ридер                428 non-null    object
#  4   Мышь                      56 non-null     float64
#  5   Цена                      428 non-null    float64
#  6   Количество ядер           428 non-null    float64
#  7   Стандарт Wi-Fi            428 non-null    object
#  8   Количество отзывов        428 non-null    float64
#  9   Название                  428 non-null    object
#  10  Операционная система      428 non-null    int32
#  11  Клавиатура                54 non-null     float64
#  12  link                      428 non-null    object
#  13  Рейтинг                   428 non-null    float64
#  14  Блок питания              369 non-null    float64
#  15  Разъем для наушников      428 non-null    float64
#  16  Графика                   428 non-null    int32
#  17  Объем оперативной памяти  428 non-null    float64
#  18  Разъем для микрофона      428 non-null    float64
#  19  Тип вилки                 428 non-null    object
# dtypes: float64(12), int32(3), object(5)
# memory usage: 62.0+ KB
# C:\Users\ilya\AppData\Local\Temp\ipykernel_11888\3155891446.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_full = df1.loc[:, column]

# %%
column = set(df1.columns) & set(df2.columns)

df_full = df1.loc[:, column]

df_full.drop(columns = ['Кард-ридер', 'Стандарт Wi-Fi','link', 'Тип вилки'], inplace = True)

df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Процессор                 428 non-null    int32
#  1   Гарантия                  428 non-null    float64
#  2   Объем SSD                 428 non-null    float64
#  3   Мышь                      56 non-null     float64
#  4   Цена                      428 non-null    float64
#  5   Количество ядер           428 non-null    float64
#  6   Количество отзывов        428 non-null    float64
#  7   Название                  428 non-null    object
#  8   Операционная система      428 non-null    int32
#  9   Клавиатура                54 non-null     float64
#  10  Рейтинг                   428 non-null    float64
#  11  Блок питания              369 non-null    float64
#  12  Разъем для наушников      428 non-null    float64
#  13  Графика                   428 non-null    int32
#  14  Объем оперативной памяти  428 non-null    float64
#  15  Разъем для микрофона      428 non-null    float64
# dtypes: float64(12), int32(3), object(1)
# memory usage: 48.6+ KB
# C:\Users\ilya\AppData\Local\Temp\ipykernel_11888\1233808231.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_full = df1.loc[:, column]

# %%
df1['Количество отзывов'] = pd.DataFrame({'Количество отзывов': np.random.normal(loc=10, scale=5, size=100)}).round(0)
df2['Количество отзывов'] = pd.DataFrame({'Количество отзывов': np.random.normal(loc=10, scale=5, size=100)}).round(0)

df1['Количество отзывов'] = df1['Количество отзывов'].clip(1, 30)
df1['Количество отзывов'] = df1['Количество отзывов'].clip(1, 30)

# %%
df1 = df1.fillna(0)
df2 = df2.fillna(0)

# %%
column = df_full.columns

df1 = df1.loc[:, column]
df2 = df2.loc[:, column]

df1.to_csv(f'data_citilink.csv', index=False)
df2.to_csv(f'data_eldorado.csv', index=False)
