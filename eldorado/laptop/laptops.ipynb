# %%
from selenium import webdriver
import numpy as np

import time
from selenium import webdriver

from selenium.webdriver.common.by import By
#from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
df = pd.read_csv('laptops.csv')

# %%
import re
from selenium.webdriver import Keys, ActionChains

from selenium.common.exceptions import ElementClickInterceptedException

import pyautogui
import warnings
warnings.filterwarnings("ignore")


options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
options.page_load_strategy = 'eager'
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)

#DesiredCapabilities.CHROME = None

driver.maximize_window()
driver.get("https://www.eldorado.ru/d/noutbuki-i-aksessuary/")

        
try:
    try:
        element = driver.find_element(By.XPATH, '/html/body/div[4]')
        driver.execute_script("arguments[0].remove();", element)
    except Exception:
        pass
except ElementClickInterceptedException:
    pass



#driver.back()
try: 
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
except ElementClickInterceptedException:
    pass

data_link = pd.read_csv('./data/data_link_laptops.csv')
link = dict()
start_page = 1
start_card = 1
number_of_reviews = (start_page - 1) * 34

#if start_page > 1:
#    for j in range(1, start_page):
#        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#            continue
#        else:
#            try:
#                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
#                driver.find_element(By.CLASS_NAME, 'next').click()
#            except Exception:
#                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#                    continue


for num in range (start_page, 15):
    time.sleep(2)
    print("num = ", num)
    for i in range(start_card, 37):
        #print("i = ", i)
        #time.sleep(2)
        #   Переход на страницу товара
        try: 
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print(search_box.get_attribute("href"))     
            #print("1!")
        except Exception as e:
            pass
            #print("1)")
        try:                                            
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print("2!")
        except Exception as e:
            pass

        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
            driver.get("https://www.eldorado.ru/d/noutbuki-i-aksessuary/")            
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass
            try: 
                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
                driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
            except ElementClickInterceptedException:
                continue
            for j in range(1, num):
                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                    continue
                else:
                    try:
                        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
                        driver.find_element(By.CLASS_NAME, 'next').click()
                    except Exception:
                        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                            continue

        link.update({'link': search_box.get_attribute("href")})                         
        data_link = data_link.append(link, ignore_index=True) 
        data_link.to_csv(f'./data/data_link_laptops.csv', index=False)

        try:
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass
        except ElementClickInterceptedException:
            pass

        link.clear()
    start_card = 1
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
    driver.find_element(By.CLASS_NAME, 'next').click()
# Out:
# num =  1
# num =  2
# num =  3
# num =  4
# num =  5
# num =  6
# num =  7
# num =  8
# num =  9
# num =  10
# num =  11
# num =  12
# num =  13
# num =  14
# num =  15
# num =  16
# num =  17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# a:\Учёба\практика 2 курс\laptops.ipynb Cell 5 in <cell line: 61>()
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/laptops.ipynb#W4sZmlsZQ%3D%3D?line=79'>80</a> except Exception as e:
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/laptops.ipynb#W4sZmlsZQ%3D%3D?line=80'>81</a>     pass
# ---> <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/laptops.ipynb#W4sZmlsZQ%3D%3D?line=82'>83</a> if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/laptops.ipynb#W4sZmlsZQ%3D%3D?line=83'>84</a>     driver.get("https://www.eldorado.ru/d/noutbuki-i-aksessuary/")
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/laptops.ipynb#W4sZmlsZQ%3D%3D?line=84'>85</a>     try:
#
# File a:\python\lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File a:\python\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File a:\python\lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     341     elif "sessionId" not in params:
#     342         params["sessionId"] = self.session_id
# --> 344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
#     346     self.error_handler.check_response(response)
#
# File a:\python\lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File a:\python\lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File a:\python\lib\site-packages\urllib3\request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File a:\python\lib\site-packages\urllib3\request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File a:\python\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File a:\python\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File a:\python\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File a:\python\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File a:\python\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File a:\python\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File a:\python\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File a:\python\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import re
from selenium.webdriver import Keys, ActionChains
from selenium.common.exceptions import ElementClickInterceptedException
import pyautogui
import warnings
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

warnings.filterwarnings("ignore")

options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
options.page_load_strategy = 'eager'
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)

#DesiredCapabilities.CHROME = None

driver.maximize_window()
driver.get("https://www.eldorado.ru/d/noutbuki-i-aksessuary/")


#print("lest go")
time.sleep(5)
#print("3")

#   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img')))
driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click()
#print("find")
#print("click")
time.sleep(2)
data_link = pd.read_csv('./data/data_link_laptops.csv')


data = dict()
data_full = pd.read_csv('./data/data_full_laptop_10.csv')

start_link = 'https://www.eldorado.ru/cat/detail/noutbuk-asus-tuf-gaming-a15-fa506ihr-us51/'
start_index = data_link[data_link['link'] == start_link].index[0]
i = start_index

driver.stop_client()

for link_from_data in data_link.loc[start_index:, 'link']:
    #print("1")
    driver.get(link_from_data)

    if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:

        time.sleep(10)
        driver.get("https://www.eldorado.ru/d/noutbuki-i-aksessuary/")


        #print("lest go")
        time.sleep(5)
        #print("3")

        #   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
        WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img')))
        driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click()
        continue

    #print("2")
    time.sleep(2)
    
    try:

        #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1

        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    try:

        #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1

        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    #print(rating, number)
    

    try:                                   
        name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
    except Exception:
        pass
    try:                                   
        name = driver.find_element(By.XPATH, f'/html/body/div[6]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
    except Exception:
        pass
    
    try:                                   
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
    except Exception:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
    except Exception:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
    except Exception:
        pass
    
    data.update({"Название": name, "Цена": price})
    try:
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()
    except Exception:
        pass
    try:
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
    except Exception:
        pass    

    for j in range(1,70):
        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
                                                    #/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[46]/td[2]
            value = value.replace('\n', '')
            value = value.replace("Другие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except Exception:
            pass
            #print("Элемент не найден")

        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
    
            value = value.replace('\n', '')
            value = value.replace("Другие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except Exception:
            pass
            #print("Элемент не найден")

    data_full = data_full.append(data, ignore_index=True) 
    i += 1
    if i % 10 == 0:
        data_full.to_csv(f'./data/data_full_laptop_{i}.csv', index=False)
    data.clear()
    print(f"Card: {i} FINISHED !")
# Out:
# Card: 12 FINISHED !
# Card: 13 FINISHED !
# Card: 14 FINISHED !
# Card: 15 FINISHED !
# Card: 16 FINISHED !
# Card: 17 FINISHED !
# Card: 18 FINISHED !
# Card: 19 FINISHED !
# Card: 20 FINISHED !
# Card: 21 FINISHED !
# Card: 22 FINISHED !
# Card: 23 FINISHED !
# Card: 24 FINISHED !
# Card: 25 FINISHED !
# Card: 26 FINISHED !
# Card: 27 FINISHED !
# Card: 28 FINISHED !
# Card: 29 FINISHED !
# Card: 30 FINISHED !
# Card: 31 FINISHED !
# Card: 32 FINISHED !
# Card: 33 FINISHED !
# Card: 34 FINISHED !
# Card: 35 FINISHED !
# Card: 36 FINISHED !
# Card: 37 FINISHED !
# Card: 38 FINISHED !
# Card: 39 FINISHED !
# Card: 40 FINISHED !
# Card: 41 FINISHED !
# Card: 42 FINISHED !
# Card: 43 FINISHED !
# Card: 44 FINISHED !
# Card: 45 FINISHED !
# Card: 46 FINISHED !
# Card: 47 FINISHED !
# Card: 48 FINISHED !
# Card: 49 FINISHED !
# Card: 50 FINISHED !
# Card: 51 FINISHED !
# Card: 52 FINISHED !
# Card: 53 FINISHED !
# Card: 54 FINISHED !
# Card: 55 FINISHED !
# Card: 56 FINISHED !
# Card: 57 FINISHED !
# Card: 58 FINISHED !
# Card: 59 FINISHED !
# Card: 60 FINISHED !
# Card: 61 FINISHED !
# Card: 62 FINISHED !
# Card: 63 FINISHED !
# Card: 64 FINISHED !
# Card: 65 FINISHED !
# Card: 66 FINISHED !
# Card: 67 FINISHED !
# Card: 68 FINISHED !
# Card: 69 FINISHED !
# Card: 70 FINISHED !
# Card: 71 FINISHED !
# Card: 72 FINISHED !
# Card: 73 FINISHED !
# Card: 74 FINISHED !
# Card: 75 FINISHED !
# Card: 76 FINISHED !
# Card: 77 FINISHED !
# Card: 78 FINISHED !
# Card: 79 FINISHED !
# Card: 80 FINISHED !
# Card: 81 FINISHED !
# Card: 82 FINISHED !
# Card: 83 FINISHED !
# Card: 84 FINISHED !
# Card: 85 FINISHED !
# Card: 86 FINISHED !
# Card: 87 FINISHED !
# Card: 88 FINISHED !
# Card: 89 FINISHED !
# Card: 90 FINISHED !
# Card: 91 FINISHED !
# Card: 92 FINISHED !
# Card: 93 FINISHED !
# Card: 94 FINISHED !
# Card: 95 FINISHED !
# Card: 96 FINISHED !
# Card: 97 FINISHED !
# Card: 98 FINISHED !
# Card: 99 FINISHED !
# Card: 100 FINISHED !
# Card: 101 FINISHED !
# Card: 102 FINISHED !
# Card: 103 FINISHED !
# Card: 104 FINISHED !
# Card: 105 FINISHED !
