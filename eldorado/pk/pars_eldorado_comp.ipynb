# %%
from selenium import webdriver
import numpy as np

import time
from selenium import webdriver

from selenium.webdriver.common.by import By
#from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
import re
from selenium.webdriver import Keys, ActionChains

from selenium.common.exceptions import ElementClickInterceptedException

import pyautogui
import warnings
warnings.filterwarnings("ignore")


options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
options.page_load_strategy = 'eager'
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)

#DesiredCapabilities.CHROME = None

driver.maximize_window()
time.sleep(3)
driver.get("https://www.eldorado.ru/d/kompyutery-i-monitory/")
time.sleep(3)
driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click


driver.get("https://www.eldorado.ru/c/kompyutery/")

        
try:
    try:
        element = driver.find_element(By.XPATH, '/html/body/div[4]')
        driver.execute_script("arguments[0].remove();", element)
    except Exception:
        pass
except ElementClickInterceptedException:
    pass


if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
    driver.get("https://www.eldorado.ru/d/kompyutery-i-monitory/")            
    try:
        element = driver.find_element(By.XPATH, '/html/body/div[4]')
        driver.execute_script("arguments[0].remove();", element)
    except Exception:
        pass

#driver.back()
try: 
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
except ElementClickInterceptedException:
    pass

data_link = pd.read_csv('./data/eldorado/data_link_laptops.csv')
link = dict()
start_page = 1
start_card = 1
number_of_reviews = (start_page - 1) * 34

#if start_page > 1:
#    for j in range(1, start_page):
#        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#            continue
#        else:
#            try:
#                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
#                driver.find_element(By.CLASS_NAME, 'next').click()
#            except Exception:
#                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#                    continue


for num in range (start_page, 15):
    time.sleep(2)
    print("num = ", num)
    for i in range(start_card, 37):
        #print("i = ", i)
        #time.sleep(2)
        #   Переход на страницу товара
        try: 
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print(search_box.get_attribute("href"))     
            #print("1!")
        except Exception as e:
            pass
            #print("1)")
        try:                                            
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print("2!")
        except Exception as e:
            pass

        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
            driver.get("https://www.eldorado.ru/c/kompyutery/")            
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass
            try: 
                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
                driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
            except ElementClickInterceptedException:
                continue
            for j in range(1, num):
                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                    continue
                else:
                    try:
                        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
                        driver.find_element(By.CLASS_NAME, 'next').click()
                    except Exception:
                        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                            continue

        link.update({'link': search_box.get_attribute("href")})                         
        data_link = data_link.append(link, ignore_index=True) 
        data_link.to_csv(f'./data/eldorado/data_link_laptops.csv', index=False)

        try:
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass
        except ElementClickInterceptedException:
            pass

        link.clear()
    start_card = 1
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
    driver.find_element(By.CLASS_NAME, 'next').click()
# Out:
# num =  1
# num =  2
# num =  3
# num =  4
# num =  5
# num =  6
# num =  7
# num =  8
# num =  9
# num =  10
# num =  11
# num =  12
# num =  13
# num =  14

# %%
import re
from selenium.webdriver import Keys, ActionChains
from selenium.common.exceptions import ElementClickInterceptedException
import pyautogui
import warnings
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

warnings.filterwarnings("ignore")

options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
options.page_load_strategy = 'eager'
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)

#DesiredCapabilities.CHROME = None

driver.maximize_window()
time.sleep(3)
driver.get("https://www.eldorado.ru/d/kompyutery-i-monitory/")
time.sleep(5)
driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click




#print("lest go")
time.sleep(5)
#print("3")

#   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img')))
driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click()
#print("find")
#print("click")
time.sleep(2)
data_link = pd.read_csv('./data/eldorado/data_link_laptops.csv')


data = dict()
data_full = pd.read_csv('./data/eldorado/data_full_comp.csv')

start_link = 'https://www.eldorado.ru/cat/detail/igrovoy-kompyuter-thunderobot-alpha-d-i5-12400-16gb-ssd512-gtx1650-dos/'
start_index = data_link[data_link['link'] == start_link].index[0]
i = start_index

driver.stop_client()

for link_from_data in data_link.loc[start_index:, 'link']:
    #print("1")
    driver.get(link_from_data)


    if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:

        start_index = data_link[data_link['link'] == link_from_data].index[0]
        time.sleep(10)
        driver.get("https://www.eldorado.ru/d/kompyutery-i-monitory/")
        time.sleep(5)
        driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click
        time.sleep(5)
        
        driver.get(link_from_data)



    #print("2")
    time.sleep(2)
    
    try:

        #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1

        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    try:

        #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1

        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    #print(rating, number)
    

    try:                                   
        name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
    except Exception:
        pass
    try:                                   
        name = driver.find_element(By.XPATH, f'/html/body/div[6]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
    except Exception:
        pass
    
    try:                                   
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
    except Exception:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
    except Exception:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
    except Exception:
        pass
    
    data.update({"Название": name, "Цена": price})
    data.update({"link": link_from_data})

    try:
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()
    except Exception:
        pass
    try:                               
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
    except Exception:
        pass   

    try:                               
        driver.find_element(By.XPATH, '/html/body/div[6]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]').click()
    except Exception:
        pass  

     

    for j in range(1,70):
        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
                                                    #/html/body/div[6]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[1]/td[1]
            value = value.replace('\n', '')
            value = value.replace("Другие товары", "")
            
            print(param," : ", value)
            data.update({param: value})
        except Exception:
            pass
            #print("Элемент не найден")

        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
    
            value = value.replace('\n', '')
            value = value.replace("Другие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except Exception:
            pass
            #print("Элемент не найден")

        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[6]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[6]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
                                                    #/html/body/div[6]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[1]/td[1]
            value = value.replace('\n', '')
            value = value.replace("Другие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except Exception:
            pass
            #print("Элемент не найден")

    data_full = data_full.append(data, ignore_index=True) 
    i += 1
    if i % 10 == 0:
        data_full.to_csv(f'./data/eldorado/data_full_comp.csv', index=False)
    data.clear()
    print(f"Card: {i} FINISHED !")
# Out:
# Card: 1 FINISHED !
# Card: 2 FINISHED !
# Card: 3 FINISHED !
# Card: 4 FINISHED !
# Card: 5 FINISHED !
# Card: 6 FINISHED !
# Card: 7 FINISHED !
# Card: 8 FINISHED !
# Card: 9 FINISHED !
# Card: 10 FINISHED !
# Card: 11 FINISHED !
# Card: 12 FINISHED !
# Card: 13 FINISHED !
# Card: 14 FINISHED !
# Card: 15 FINISHED !
# Card: 16 FINISHED !
# Card: 17 FINISHED !
# Card: 18 FINISHED !
# Card: 19 FINISHED !
# Card: 20 FINISHED !
# Card: 21 FINISHED !
# Card: 22 FINISHED !
# Card: 23 FINISHED !
# Card: 24 FINISHED !
# Card: 25 FINISHED !
# Card: 26 FINISHED !
# Card: 27 FINISHED !
# Card: 28 FINISHED !
# Card: 29 FINISHED !
# Card: 30 FINISHED !
# Card: 31 FINISHED !
# Card: 32 FINISHED !
# Card: 33 FINISHED !
# Card: 34 FINISHED !
# Card: 35 FINISHED !
# Card: 36 FINISHED !
# Card: 37 FINISHED !
# Card: 38 FINISHED !
# Card: 39 FINISHED !
# Card: 40 FINISHED !
# Card: 41 FINISHED !
# Card: 42 FINISHED !
# Card: 43 FINISHED !
# Card: 44 FINISHED !
# Card: 45 FINISHED !
# Card: 46 FINISHED !
# Card: 47 FINISHED !
