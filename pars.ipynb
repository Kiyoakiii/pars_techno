# %%
from selenium import webdriver
import numpy as np

import time
from selenium import webdriver

from selenium.webdriver.common.by import By
#from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
df = pd.read_csv('data_TV.csv')

# %%
df

# %%
#from selenium.common.exceptions import NoSuchElementException
#options = webdriver.ChromeOptions()
#prefs = {"profile.default_content_setting_values.notifications" : 2}
#options.add_experimental_option("prefs",prefs)
#service = Service(executable_path="chromedriver.exe")
#driver = webdriver.Chrome(service=service, options=options)
#print("started !")
## Открытие страницы Eldorado
#driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
#print("lest go")
#time.sleep(5)
#print("3")
#
##   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#
#driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]').click()
#print("find")
#
#
#WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[6]/div/button')))
#driver.find_element(By.XPATH, '/html/body/div[2]/div[6]/div/button').click()
#WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a')))
##       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[3]/div[2]/a
#search_box = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a').click()
#
##text = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[3]').text
#
##print(text[0:250])
#
#new_row = dict()
##driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
##text = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]').text
##print(text[0:250])
#driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
#
##Страна
##param = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[1]/td[1]').text
##print(param[0:250])
##value = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[1]/td[2]').text
##print(value[0:250])
##new_row.update({param:  value})
##
##param = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[2]/td[1]').text
##print(param[0:250])
##value = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[2]/td[2]').text
##print(value[0:250])
##new_row.update({param:  value})
#
#
#for i in range(1,50):
#    try:
#        param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{i}]/td[1]').text
#        value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{i}]/td[2]').text
#
#        value = value.replace("\nДругие товары", "")
#
#        print(param," : ", value)
#        new_row.update({param: value})
#    except NoSuchElementException:
#        print("Элемент не найден")
#
#df = df.append(new_row, ignore_index=True) 
#
##/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[4]/td[2]/a
##/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[4]/td[2]/text()
#
#print("completed !")

# %%
#
#
## Удаление слова "Другие товары" из каждой строки
#str_arr = [s.replace('Другие товары', '') for s in text]
#
#combined_str = ''.join(str_arr)
##print(combined_str)
## Замена "Другие товары" на пустую строку
#result_str = combined_str.replace('Другие товары', '')
#
#substrings = ['ОБЩИЕ', 'ЭКРАН', 'ФУНКЦИИ', 'ОБРАБОТКА ИЗОБРАЖЕНИЯ', 'ТЮНЕР', 'ЗВУКОВАЯ СИСТЕМА', 'ИНТЕРФЕЙСЫ', 'КОМПЛЕКТАЦИЯ','КРЕПЛЕНИЕ', 'ГАБАРИТЫ И ВЕС']
#for col in substrings:
#    result_str = result_str.replace(col, '')
#
##print(result_str)
#
## Разделение строки на строки по символу новой строки
#lines = result_str.split('\n')
#
## Удаление пустых строк
#non_empty_lines = [line.strip() for line in lines if line.strip()]
#
#print(non_empty_lines)

# %%
#
#
#column_names = df.columns.tolist()
#
#my_string = ', '.join(non_empty_lines)
#
#new_row = dict()
#
#last_index = 0
#
#for idx, col in enumerate(column_names):
#    #match = re.search(rf"\b{col}\b", my_string)
#    #if match:
#    #    print("Match found at index:", match.start())
#    #else:
#    #    print("Match not found")
#    print(col)
#    index_start = my_string.find(col, last_index)
#    if idx != len(column_names) - 1:
#        count = 1
#        index_end = my_string.find(column_names[idx + 1])
#        while index_end == -1:
#            if idx + count < len(my_string):
#                index_end = my_string.find(column_names[idx + count])
#                count += 1
#            else: 
#                index_end = 0
#        
#        print(last_index, index_start, len(col), index_end)
#        if index_start != -1:
#            print("my str: ", my_string[index_start+len(col)+1: index_end-2])
#            new_row.update({col: my_string[index_start+len(col)+1: index_end-2]})
#        else: 
#            new_row.update({col: 'Nan'})
#            #print(f'Подстрока "{col}" найдена в строке "{my_string}" на позиции {index_start}')
#
#        
#    else :
#        if index_start != -1:
#            new_row.update({col: my_string[index_start+len(col)+1: len(my_string)]})
#        else:
#            new_row.update({col: 'Nan'})
#
#    if index_end != -1:
#        last_index = index_end
#            
#
#print(new_row)
#df = df.append(new_row, ignore_index=True)

# %%
from selenium.common.exceptions import NoSuchElementException

options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
#print("started !")
# Открытие страницы Eldorado
driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
#print("lest go")
time.sleep(5)
#print("3")

#   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img')))
driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[1]/img').click()
#print("find")
                            

WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[6]/div/button')))
driver.find_element(By.XPATH, '/html/body/div[2]/div[6]/div/button').click()
WebDriverWait(driver, 50).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[1]/div[2]/a')))
search_box = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[1]/div[2]/a').click()

new_row = dict()

try:
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a')))
    driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
except NoSuchElementException:
    driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()


for i in range(1,50):
    try:
        param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{i}]/td[1]').text
        value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{i}]/td[2]').text

        value = value.replace("\nДругие товары", "")

        #print(param," : ", value)
        new_row.update({param: value})
    except NoSuchElementException:
        pass
        #print("Элемент не найден")

df = df.append(new_row, ignore_index=True) 

#/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[4]/td[2]/a
#/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[4]/td[2]/text()

print("completed !")

# %%
import re
from selenium.webdriver import Keys, ActionChains

from selenium.common.exceptions import ElementClickInterceptedException
column_names = df.columns.tolist()
import pyautogui
import warnings
warnings.filterwarnings("ignore")



start_page = 17
start_card = 19
number_of_reviews = (start_page - 1) * 34 + 10

for num in range (start_page, 90):
    
    for i in range(start_card, 36):
        driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")

        
        try:
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except NoSuchElementException:
                pass
        except ElementClickInterceptedException:
            pass



        #driver.back()
        try: 
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
            driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
        except ElementClickInterceptedException:
            continue
            
        time.sleep(2)
        if num > 1:
            for j in range(1, num):
                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                    continue
                else:
                    try:
                        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
                        driver.find_element(By.CLASS_NAME, 'next').click()
                    except Exception:
                        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                            continue


        
        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
            continue



        time.sleep(3)
        #   Переход на страницу товара
        try: 
            #   Переход на страницу товара
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').click()
        except Exception:
            pass 
        try: 
            #   Переход на страницу товара
            search_box = driver.find_element(By.XPATH, f'/ html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a').click()
        except Exception:
            pass                                         
        new_row = dict()
        #   Получение рейтинга
        try:
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
            rating = 0
            for h in range(1, 6):
                if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                    break
                else:
                    rating += 1
            new_row.update({'Рейтинг': rating})
            num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
            if num_rating == "Написать отзыв":
                number = 0
            else:
                number = int(re.search(r'\d+', num_rating).group())
            new_row.update({'Количество отзывов': number})
        except Exception:
             pass
        try:
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
            rating = 0
            for h in range(1, 6):
                if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                    break
                else:
                    rating += 1
            new_row.update({'Рейтинг': rating})
            num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
            if num_rating == "Написать отзыв":
                number = 0
            else:
                number = int(re.search(r'\d+', num_rating).group())
            new_row.update({'Количество отзывов': number})
        except Exception:
             pass
        #print(rating, number)
        


        name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
        try:                                   
            price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
        except NoSuchElementException:
            pass
        try:
            price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
        except NoSuchElementException:
            pass
        try:
            price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
        except NoSuchElementException:
            pass
        
        new_row.update({"Название": name, "Цена": price})
        try:
            driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
        except NoSuchElementException:
            driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()


        for j in range(1,50):
            try:
                
                param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text

                value = value.replace("\nДругие товары", "")
                
                #print(param," : ", value)
                new_row.update({param: value})
            except NoSuchElementException:
                pass
                #print("Элемент не найден")

            try:
                
                param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
      
                value = value.replace("\nДругие товары", "")
                
                #print(param," : ", value)
                new_row.update({param: value})
            except NoSuchElementException:
                pass
                #print("Элемент не найден")

        

        df = df.append(new_row, ignore_index=True) 
        df.to_csv(f'./data/data_{number_of_reviews}.csv', index=False)

        new_row.clear()
        #print(df)
        print(f"page: {num}, card: {i} FINISHED !")
        number_of_reviews += 1
    start_card = 1

# %% [markdown]
# ### этот код пробегается по вссем страницам и парсит ссылки товаров

# %%
import re
from selenium.webdriver import Keys, ActionChains

from selenium.common.exceptions import ElementClickInterceptedException

import pyautogui
import warnings
warnings.filterwarnings("ignore")
#
#driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
#
#        
#try:
#    try:
#        element = driver.find_element(By.XPATH, '/html/body/div[4]')
#        driver.execute_script("arguments[0].remove();", element)
#    except NoSuchElementException:
#        pass
#except ElementClickInterceptedException:
#    pass
#
#
#
##driver.back()
#try: 
#    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
#    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
#except ElementClickInterceptedException:
#    pass
#
data_link = pd.read_csv('./data/data_link.csv')
link = dict()
start_page = 62
start_card = 1
number_of_reviews = (start_page - 1) * 34 + 10

#if start_page > 1:
#    for j in range(1, start_page):
#        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#            continue
#        else:
#            try:
#                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
#                driver.find_element(By.CLASS_NAME, 'next').click()
#            except Exception:
#                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
#                    continue


for num in range (start_page, 96):
    time.sleep(2)
    print("num = ", num)
    for i in range(start_card, 37):
        #print("i = ", i)
        #time.sleep(2)
        #   Переход на страницу товара
        try: 
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print(search_box.get_attribute("href"))     
            #print("1!")
        except Exception as e:
            pass
            #print("1)")
        try:                                            
            #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')))
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/ul/li[{i}]/div[2]/a')
            #print("2!")
        except Exception as e:
            pass

        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
            driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")            
            try:
                try:
                    element = driver.find_element(By.XPATH, '/html/body/div[4]')
                    driver.execute_script("arguments[0].remove();", element)
                except NoSuchElementException:
                    pass
            except ElementClickInterceptedException:
                pass
            try: 
                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
                driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()
            except ElementClickInterceptedException:
                continue
            for j in range(1, num):
                if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                    continue
                else:
                    try:
                        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
                        driver.find_element(By.CLASS_NAME, 'next').click()
                    except Exception:
                        if "Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]:
                            continue

        link.update({'link': search_box.get_attribute("href")})                         
        data_link = data_link.append(link, ignore_index=True) 
        data_link.to_csv(f'./data/data_link.csv', index=False)

        try:
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except NoSuchElementException:
                pass
        except ElementClickInterceptedException:
            pass

        link.clear()
    start_card = 1
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'next')))
    driver.find_element(By.CLASS_NAME, 'next').click()
# Out:
# num =  62
# num =  63
# num =  64
# num =  65
# num =  66
# num =  67
# num =  68
# num =  69
# num =  70
# num =  71
# num =  72
# num =  73
# num =  74
# num =  75
# num =  76
# num =  77
# num =  78
# num =  79
# num =  80
# num =  81
# num =  82
# num =  83
# num =  84
# num =  85
# num =  86
# num =  87
# num =  88
# num =  89
# num =  90
# num =  91
# num =  92
# num =  93
# num =  94
# num =  95

# %%
data_link = pd.read_csv('./data/data_link.csv')

data = dict()

for link_from_data in data_link["link"]:
    print(link_from_data)
# Out:
# https://www.eldorado.ru/cat/detail/led-televizor-vitjaz-24lh0201/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-55-haier-55-smart-tv-s7-dh1vmed01ru/
# https://www.eldorado.ru/cat/detail/led-televizor-40-hi-vhix-40f152msy/
# https://www.eldorado.ru/cat/detail/led-televizor-32-artel-ua32h3200/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-haier-65-smart-tv-ax-pro-dh1vw3d01ru/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-toshiba-65c350le/
# https://www.eldorado.ru/cat/detail/led-televizor-32-skyworth-32ste6600-590138188/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-haier-50-smart-tv-s3/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-philips-43pus7406-60/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-toshiba-43c350le/
# https://www.eldorado.ru/cat/detail/led-televizor-43-hi-vhix-43f169msy/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-haier-65-smart-tv-s3/
# https://www.eldorado.ru/cat/detail/led-televizor-32-hi-vhix-32f199msa/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-oled-televizor-65-haier-h65s9ug-pro/
# https://www.eldorado.ru/cat/detail/led-televizor-32-candy-uno-32/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-samsung-ue43au7002u-71674424/
# https://www.eldorado.ru/cat/detail/led-televizor-32-haier-smart-tv-mx/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-samsung-ue50au7002u-71662653/
# https://www.eldorado.ru/cat/detail/led-televizor-40-toshiba-40v35le/
# https://www.eldorado.ru/cat/detail/led-televizor-vitjaz-32lh0202/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-lg-50uq76003ld/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-hisense-55a6bg/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-artel-ua50h3502/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-hisense-65a6bg/
# https://www.eldorado.ru/cat/detail/led-televizor-32-artel-a32kh5500/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-grundig-50-gfu-7800b/
# https://www.eldorado.ru/cat/detail/led-televizor-43-artel-ua43h3401/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-yandex-s-alisoy-yndx-00071/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-55-hisense-55e7hq/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-yandex-s-alisoy-yndx-00072/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-65-hisense-55u7hq/
# https://www.eldorado.ru/cat/detail/led-televizor-50-hi-vhix-50u169msy-/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-philips-55pus7406-60/
# https://www.eldorado.ru/cat/detail/led-televizor-32-toshiba-32v35le/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-grundig-43-ggu-7902a/
# https://www.eldorado.ru/cat/detail/televizor-toshiba-43c450ke/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-hisense-50a6bg/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-haier-55-smart-tv-s1/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-artel-a55lu8500/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-philips-50pus8057-60/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-haier-43-smart-tv-s3/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-haier-50-smart-tv-s1/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-haier-43-smart-tv-s1/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-50-hisense-50e7hq/
# https://www.eldorado.ru/cat/detail/led-televizor-32-haier-32-smart-tv-s1/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-hisense-43a6bg/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-haier-55-smart-tv-ax-pro-dh1vmfd00ru/
# https://www.eldorado.ru/cat/detail/led-televizor-32-hisense-32a4k/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-philips-50pus7406-60/
# https://www.eldorado.ru/cat/detail/led-televizor-32-realme-rmt101/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-realme-tv-43-rmv2004/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-haier-43-smart-tv-s1-74550562/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-43-hisense-43e7hq/
# https://www.eldorado.ru/cat/detail/led-televizor-40-hisense-40a4k/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-65-hisense-65e7hq/
# https://www.eldorado.ru/cat/detail/led-televizor-40-hisense-40a4bg/
# https://www.eldorado.ru/cat/detail/led-televizor-40-hi-vhit-40f152ms/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-grundig-55-gfu-7800b/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-65-hisense-65u8hq/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-grundig-43-gfu-7800b/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50

# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-samsung-ue65bu8000uxce/
# https://www.eldorado.ru/cat/detail/led-televizor-32-lg-32lq63006la-arub/
# https://www.eldorado.ru/cat/detail/smart-led-televizor-32-econ-ex-32hs019b/
# https://www.eldorado.ru/cat/detail/led-televizor-32-blackton-bt-32s02b-black/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-tcl-43p735-smart-black/
# https://www.eldorado.ru/cat/detail/led-televizor-43-haier-43-smart-tv-dx-light/
# https://www.eldorado.ru/cat/detail/led-televizor-40-fusion-fltv-40a410/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-lg-nanocell-55nano806pa-74541911/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-oled-televizor-55-tcl-55p735-smart-black/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-55-lg-nanocell-55nano766qa-arub/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-50-erisson-50ulea73t2sm/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-philips-the-one-65pus8505-60/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-65-sony-kd65x81j-74542936/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-70-samsung-ue70au7100u-74542938/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-75-samsung-qe75q80aau-74542939/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-75-sony-kd75x81j-74542940/
# https://www.eldorado.ru/cat/detail/led-televizor-32-erisson-32lea70t2/
# https://www.eldorado.ru/cat/detail/led-televizor-43-harper-43f690ts-74542946/
# https://www.eldorado.ru/cat/detail/led-televizor-43-vekta-ld-43sf4815bs/
# https://www.eldorado.ru/cat/detail/led-televizor-40-prestigio-wr-smart-ptv40ss06ycisml/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-led-televizor-43-thomson-lcd-t43usl7010-black/
# https://www.eldorado.ru/cat/detail/ultra-hd-4k-qled-televizor-55-haier-55-smart-tv-ax-pro/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/
# https://www.eldorado.ru/cat/detail/ultra-hd-8k-qned-miniled-televizor-75-lg-75qned996pb-74552548/

# %%
import re
from selenium.webdriver import Keys, ActionChains
from selenium.common.exceptions import ElementClickInterceptedException
import pyautogui
import warnings

warnings.filterwarnings("ignore")

options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()


WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[16]/div/button')))
driver.find_element(By.XPATH, '/html/body/div[16]/div/button').click
data_link = pd.read_csv('./data/data_link.csv')

data = dict()

i = 0

for link_from_data in data_link["link"]: 

    driver.get(link_from_data)

    try:
        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1
        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    try:
        WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
        rating = 0
        for h in range(1, 6):
            if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                break
            else:
                rating += 1
        data.update({'Рейтинг': rating})
        num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
        if num_rating == "Написать отзыв":
            number = 0
        else:
            number = int(re.search(r'\d+', num_rating).group())
        data.update({'Количество отзывов': number})
    except Exception:
            pass
    #print(rating, number)
    


    name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
    try:                                   
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
    except NoSuchElementException:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
    except NoSuchElementException:
        pass
    try:
        price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
    except NoSuchElementException:
        pass
    
    data.update({"Название": name, "Цена": price})
    try:
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
    except NoSuchElementException:
        driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()


    for j in range(1,50):
        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text

            value = value.replace("\nДругие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except NoSuchElementException:
            pass
            #print("Элемент не найден")

        try:
            
            param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
            value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
    
            value = value.replace("\nДругие товары", "")
            
            #print(param," : ", value)
            data.update({param: value})
        except NoSuchElementException:
            pass
            #print("Элемент не найден")


    df = df.append(data, ignore_index=True) 
    i += 1
    if i % 10 == 0:
        df.to_csv(f'./data/data_full_{i}.csv', index=False)
    data.clear()
    print(f"card: {i} FINISHED !")
# Out:
# card: 1 FINISHED !
# card: 2 FINISHED !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# a:\Учёба\практика 2 курс\pars.ipynb Cell 12 in <cell line: 22>()
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/pars.ipynb#X51sZmlsZQ%3D%3D?line=41'>42</a>         pass
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/pars.ipynb#X51sZmlsZQ%3D%3D?line=42'>43</a> try:
# ---> <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/pars.ipynb#X51sZmlsZQ%3D%3D?line=43'>44</a>     WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/pars.ipynb#X51sZmlsZQ%3D%3D?line=44'>45</a>     rating = 0
#      <a href='vscode-notebook-cell:/a%3A/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%202%20%D0%BA%D1%83%D1%80%D1%81/pars.ipynb#X51sZmlsZQ%3D%3D?line=45'>46</a>     for h in range(1, 6):
#
# File a:\python\lib\site-packages\selenium\webdriver\support\wait.py:92, in WebDriverWait.until(self, method, message)
#      90     screen = getattr(exc, "screen", None)
#      91     stacktrace = getattr(exc, "stacktrace", None)
# ---> 92 time.sleep(self._poll)
#      93 if time.monotonic() > end_time:
#      94     break
#
# KeyboardInterrupt:

# %%
data_link.drop(data_link.columns.difference(['link']), 1, inplace=True)

# %%
data_link.to_csv(f'./data/data_link.csv', index=False)

# %%
search_box.text

# %%
link = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a')

# %%
print(link.get_attribute("href"))

# %%
"Access to resource was blocked." == driver.find_element(By.XPATH, '/html/body').text.split('\n')[0]

# %%
import asyncio
import re
from selenium import webdriver
import numpy as np

import time
from selenium import webdriver

from selenium.webdriver.common.by import By
#from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import NoSuchElementException

async def read_info(start_page, end_page):


    df = pd.read_csv('data_TV.csv')

    column_names = df.columns.tolist()
    #
    number_of_reviews = 1
    options = webdriver.ChromeOptions()
    prefs = {"profile.default_content_setting_values.notifications" : 2}
    options.add_experimental_option("prefs",prefs)
    service = Service(executable_path="chromedriver.exe")
    driver = webdriver.Chrome(service=service, options=options)
    driver.maximize_window()
    driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
    print("get site")
    time.sleep(5)
    print("5")
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[6]/div/button')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[6]/div/button').click()
    print("1")
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/header/div[1]/div[1]/button[1]')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/header/div[1]/div[1]/button[1]').click()
    print("2")

    async for num in range (start_page, end_page):

        async for i in range(1, 36):
            await asyncio.sleep(0)
            print("3")
            driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")

            print("4")
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass

            print("5")
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
            driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()

            print("6")
            time.sleep(2)
            if num > 1:
                print("!")   
                for j in range(1, num):
                    print("11")   
                    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'vr.wr')))
                    driver.find_element(By.CLASS_NAME, 'vr.wr').click()
                                                
            print("7")                                       
            time.sleep(3)
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').click()

            new_row = dict()
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
            rating = 0
            print("8")  
            async for h in range(1, 6):
                if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                    break
                else:
                    rating += 1
            print("9")  
            new_row.update({'Рейтинг': rating})
            num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
            if num_rating == "Написать отзыв":
                number = 0
            else:
                number = int(re.search(r'\d+', num_rating).group())
            #print(rating, number)
            print("10")  
            new_row.update({'Количество отзывов': number})


            name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
            except NoSuchElementException:
                pass
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
            except NoSuchElementException:
                pass
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
            except NoSuchElementException:
                pass
            
            new_row.update({"Название": name, "Цена": price})
            try:
                driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
            except NoSuchElementException:
                driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()

            print("13")

            for j in range(1,50):
                try:
                    
                    param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                    value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text

                    value = value.replace("\nДругие товары", "")
                    
                    print(param," : ", value)
                    new_row.update({param: value})
                except NoSuchElementException:
                    pass
                    #print("Элемент не найден")

                try:
                    
                    param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                    value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text
        
                    value = value.replace("\nДругие товары", "")
                    
                    print(param," : ", value)
                    new_row.update({param: value})
                except NoSuchElementException:
                    pass
                    #print("Элемент не найден")

            

            df = df.append(new_row, ignore_index=True) 
            if number_of_reviews % 5 ==0:
                df.to_csv(f'./data/data_asyncio_{number_of_reviews}.csv', index=False)

            new_row.clear()
            #print(df)
            print(f"page: {num}, card: {i} FINISHED !")
            number_of_reviews += 1

async def main():
    task_1 = asyncio.create_task(read_info(9, 20))
    task_2 = asyncio.create_task(read_info(20, 25))

    await asyncio.gather(task_1, task_2)

await main()

# %%
import time


def fun1(x):
    print(x**2)
    time.sleep(3)
    print('fun1 завершена')


def fun2(x):
    print(x**0.5)
    time.sleep(3)
    print('fun2 завершена')


def main():
    fun1(4)
    fun2(4)


print(time.strftime('%X'))

main()

print(time.strftime('%X'))

# %%
import asyncio
import time


async def fun1(x):
    print(x**2)
    await asyncio.sleep(3)
    print('fun1 завершена')


async def fun2(x):
    print(x**0.5)
    await asyncio.sleep(3)
    print('fun2 завершена')


async def main():
    task1 = asyncio.create_task(fun1(4))
    task2 = asyncio.create_task(fun2(4))

    await task1
    await task2


print(time.strftime('%X'))

await main()

print(time.strftime('%X'))

# %%
import asyncio
import time



async def read_info(start_page, end_page, service, options):
    
    driver = webdriver.Chrome(service=service, options=options)
    driver.maximize_window()
    driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
    print("get site")
    await asyncio.sleep(5)
    print("5")
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[6]/div/button')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[6]/div/button').click()
    print("1")
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/header/div[1]/div[1]/button[1]')))
    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/header/div[1]/div[1]/button[1]').click()
    print("2")

    for num in range (start_page, end_page):

        for i in range(1, 36):
            print("3")
            driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")

            print("4")
            try:
                element = driver.find_element(By.XPATH, '/html/body/div[4]')
                driver.execute_script("arguments[0].remove();", element)
            except Exception:
                pass

            print("5")
            WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]')))
            driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]').click()

            print("6")
            await asyncio.sleep(2)
            if num > 1:
                print("!")   
                for j in range(1, num):
                    print("11")   
                    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.CLASS_NAME, 'vr.wr')))
                    driver.find_element(By.CLASS_NAME, 'vr.wr').click()
                                                
            print("7")   
            await asyncio.sleep(3)
        
            search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').click()

            new_row = dict()

            try:
                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[5]')))
                rating = 0
                for h in range(1, 6):
                    if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                        break
                    else:
                        rating += 1
                new_row.update({'Рейтинг': rating})
                num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
                if num_rating == "Написать отзыв":
                    number = 0
                else:
                    number = int(re.search(r'\d+', num_rating).group())
                new_row.update({'Количество отзывов': number})
            except Exception:
                pass
            try:
                WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a')))
                rating = 0
                for h in range(1, 6):
                    if "star"==driver.find_element(By.XPATH, f'/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[1]/div[{h}]').get_attribute('class'):
                        break
                    else:
                        rating += 1
                new_row.update({'Рейтинг': rating})
                num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div/div[2]/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
                if num_rating == "Написать отзыв":
                    number = 0
                else:
                    number = int(re.search(r'\d+', num_rating).group())
                new_row.update({'Количество отзывов': number})
            except Exception:
                pass
            


            name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
            except NoSuchElementException:
                pass
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
            except NoSuchElementException:
                pass
            try:
                price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
            except NoSuchElementException:
                pass
            
            new_row.update({"Название": name, "Цена": price})
            try:
                driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
            except NoSuchElementException:
                driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[4]/div/ul/li[2]/a').click()

            print("13")

            for j in range(1,50):
                try:
                    
                    param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                    value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]/table/tbody/tr[{j}]/td[2]').text

                    value = value.replace("\nДругие товары", "")
                    
                    print(param," : ", value)
                    new_row.update({param: value})
                except NoSuchElementException:
                    pass
                    #print("Элемент не найден")

                try:
                    
                    param = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[1]').text
                    value = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[6]/div/div[2]/table/tbody/tr[{j}]/td[2]').text

                    value = value.replace("\nДругие товары", "")
                    
                    print(param," : ", value)
                    new_row.update({param: value})
                except NoSuchElementException:
                    pass
                    #print("Элемент не найден")

            

        df = df.append(new_row, ignore_index=True) 
        if number_of_reviews % 5 ==0:
            df.to_csv(f'./data/data_asyncio_{number_of_reviews}.csv', index=False)

        new_row.clear()
        #print(df)
        print(f"page: {num}, card: {i} FINISHED !")
        number_of_reviews += 1



async def main():
    options = webdriver.ChromeOptions()
    prefs = {"profile.default_content_setting_values.notifications" : 2}
    options.add_experimental_option("prefs",prefs)
    service = Service(executable_path="chromedriver.exe")
    task1 = asyncio.create_task(read_info(1, 10, service, options))
    task2 = asyncio.create_task(read_info(10, 20, service, options))

    await task1
    await task2


print(time.strftime('%X'))

await main()

print(time.strftime('%X'))

# %%
/html/body/div[2]/div[1]/main/div/div/div[8]/div[2]/div[1]/div[5]/ul/li[5]/a

# %%
try:
    WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, '/html/body/div/div[1]')))
    element = driver.find_element(By.XPATH, '/html/body/div[4]')
    driver.execute_script("arguments[0].remove();", element)
except ElementClickInterceptedException:
    pass

# %%
window_before = driver.window_handles[0] # May be 1 in your case
driver.switch_to_window(window_before)
driver.close()

# %%
from selenium.webdriver import Keys, ActionChains
ActionChains(driver).key_down(Keys.ALT).key_down(Keys.ARROW_LEFT).perform()

# %%
driver.get(f"https://www.eldorado.ru/c/televizory/?page={num}")

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = 'https://www.eldorado.ru/c/televizory/?page=2'
driver = webdriver.Chrome()
driver.get(url)

soup = BeautifulSoup(driver.page_source, 'html.parser')
tv_list = soup.find_all('div', {'class': 'h'})
print(len(tv_list))
for tv in tv_list:
    print(tv.text.strip())

driver.quit()

# %%
from bs4 import BeautifulSoup
import requests



url = 'https://www.citilink.ru/catalog/televizory/?p=5'

page = requests.get(url)

print(page.status_code)

filteredNews = []
allNews = []

soup = BeautifulSoup(page.text, "html.parser")
allNews = soup.findAll(class_='app-catalog-1tp0ino e1an64qs0')
print(allNews)

# %%
name = driver.find_element(By.XPATH, f'/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[1]/div/div/h1').text

try:
    price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]').text
except NoSuchElementException:
    pass
try:
    price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]').text
except NoSuchElementException:
    pass
try:
    price = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[3]/div[2]/div[2]/div[1]/div[1]/div[2]/div/div[1]').text
except NoSuchElementException:
    pass

                                       
                                       
new_row.update({"Название": name, "Цена": price})

# %%
price

# %%
num_rating = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[1]/div/div[2]/div[1]/div[3]/div[2]/div[4]/div/div[2]/div[3]/div[2]/a').text
if num_rating == "Написать отзыв":
    number = 0
else:
    number = int(re.search(r'\d+', num_rating).group())
print(rating, number)

# %%
#column_names = df.columns.tolist()
#for i in range(2, 5):
#    driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
#    #print("lest go")
#
#    #print("3")
#
#    #   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    time.sleep(2)
#    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]').click()
#    #print("find")
#    #driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').is_displayed()
#    time.sleep(3)
#    #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f"/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a")))
#
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[36]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[1]/div[2]/a
#    search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').click()
#    time.sleep(3)
#
#    #print(text[0:250])
#
##/html/body/div[12]/div[1]/div[2]/div[2]/div[7]
#    driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
#    text = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]').text
#    #print(text[0:250])
#
#    #print(f"{i} completed !")
#
#    # Удаление слова "Другие товары" из каждой строки
#    str_arr = [s.replace('Другие товары', '') for s in text]
#
#    combined_str = ''.join(str_arr)
#    #print(combined_str)
#    # Замена "Другие товары" на пустую строку
#    result_str = combined_str.replace('Другие товары', '')
#
#    substrings = ['ОБЩИЕ', 'ЭКРАН', 'ФУНКЦИИ', 'ОБРАБОТКА ИЗОБРАЖЕНИЯ', 'ТЮНЕР', 'ЗВУКОВАЯ СИСТЕМА', 'ИНТЕРФЕЙСЫ', 'КОМПЛЕКТАЦИЯ', 'ГАБАРИТЫ И ВЕС']
#    for col in substrings:
#        result_str = result_str.replace(col, '')
#
#    #print(result_str)
#
#    # Разделение строки на строки по символу новой строки
#    lines = result_str.split('\n')
#
#    # Удаление пустых строк
#    non_empty_lines = [line.strip() for line in lines if line.strip()]
#
#    
#
#    my_string = ', '.join(non_empty_lines)
#
#    new_row = dict()
#
#    last_index = 0
#
#    for idx, col in enumerate(column_names):
#        #match = re.search(rf"\b{col}\b", my_string)
#        #if match:
#        #    print("Match found at index:", match.start())
#        #else:
#        #    print("Match not found")
#        #print(col)
#        index_start = my_string.find(col, last_index)
#        if idx != len(column_names) - 1:
#            count = 1
#            index_end = my_string.find(column_names[idx + 1], last_index)
#            while index_end == -1:
#                if idx + count < len(my_string):
#                    index_end = my_string.find(column_names[idx + count])
#                    count += 1
#                else: 
#                    index_end = 0
#            
#            #print(last_index, index_start, len(col), index_end)
#            if index_start != -1:
#                new_row.update({col: my_string[index_start+len(col)+1: index_end-2]})
#            else: 
#                new_row.update({col: 'Nan'})
#                #print(f'Подстрока "{col}" найдена в строке "{my_string}" на позиции {index_start}')
#
#            #print("my str: ", my_string[index_start+len(col)+1: index_end-2])
#        else :
#            if index_start != -1:
#                new_row.update({col: my_string[index_start+len(col)+1: len(my_string)]})
#            else:
#                new_row.update({col: 'Nan'})
#
#        if index_end != -1:
#            last_index = index_end
#                
#    
#    df = df.append(new_row, ignore_index=True)
#    new_row.clear()
#    #print(df)
#    print(f"{i} FINISHED !")

# %%
df

# %%
#column_names = df.columns.tolist()
#for i in range(2, 3):
#    driver.get("https://www.eldorado.ru/d/televizory-i-aksessuary/")
#    #print("lest go")
#
#    #print("3")
#
#    #   /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    time.sleep(2)
#    driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[3]/div[2]/a[1]/span[2]').click()
#    #print("find")
#    #driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a').is_displayed()
#    time.sleep(3)
#    #WebDriverWait(driver, 10).until(expected_conditions.visibility_of_element_located((By.XPATH, f"/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[{i}]/div[2]/a")))
#
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[36]/div[2]/a
#    #       /html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[1]/div[2]/a
#    search_box = driver.find_element(By.XPATH, f'/html/body/div[2]/div[1]/main/div/div/div[7]/div[2]/div[1]/ul/li[2]/div[2]/a').click()
#    time.sleep(3)
#
#    #print(text[0:250])
#
##/html/body/div[12]/div[1]/div[2]/div[2]/div[7]
#    driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[5]/div/ul/li[2]/a').click()
#    text = driver.find_element(By.XPATH, '/html/body/div[12]/div[1]/div[2]/div[2]/div[7]/div/div[2]').text
#    #print(text[0:250])
#
#    print(f"{i} completed !")
#
#    # Удаление слова "Другие товары" из каждой строки
#    str_arr = [s.replace('Другие товары', '') for s in text]
#
#    combined_str = ''.join(str_arr)
#    #print(combined_str)
#    # Замена "Другие товары" на пустую строку
#    result_str = combined_str.replace('Другие товары', '')
#
#    substrings = ['ОБЩИЕ', 'ЭКРАН', 'ФУНКЦИИ', 'ОБРАБОТКА ИЗОБРАЖЕНИЯ', 'ТЮНЕР', 'ЗВУКОВАЯ СИСТЕМА', 'ИНТЕРФЕЙСЫ', 'КОМПЛЕКТАЦИЯ', 'ГАБАРИТЫ И ВЕС']
#    for col in substrings:
#        result_str = result_str.replace(col, '')
#
#    #print(result_str)
#
#    # Разделение строки на строки по символу новой строки
#    lines = result_str.split('\n')
#
#    # Удаление пустых строк
#    non_empty_lines = [line.strip() for line in lines if line.strip()]
#
#    
#
#    my_string = ', '.join(non_empty_lines)
#
#    new_row = dict()
#    
#    for idx, col in enumerate(column_names):
#        index_start = my_string.find(col)
#        if idx != len(column_names) - 1:
#            count = 1
#            index_end = my_string.find(column_names[idx + 1])
#            while index_end == -1:
#                index_end = my_string.find(column_names[idx + count])
#                count += 1
#            print(index_start, len(col), index_end)
#            if index_start != -1:
#                new_row.update({col: my_string[index_start+len(col)+1: index_end-2]})
#            else: 
#                new_row.update({col: 'Nan'})
#            #    print(f'Подстрока "{col}" найдена в строке "{my_string}" на позиции {index_start}')
#            #print(index_start)
#            #print("my str: ", my_string[index_start+len(col)+1: index_end-2])
#        else :
#            if index_start != -1:
#                new_row.update({col: my_string[index_start+len(col)+1: len(my_string)]})
#            else:
#                new_row.update({col: 'Nan'})
#            
#
#
#    
#    df = df.append(new_row, ignore_index=True)
#    new_row.clear()
#    #print(df)
#    print(f"{i} FINISHED !")

# %%
df.info()

# %%
df.to_csv('data.csv', index=False)
